# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #FF6347;">Self-Guided Lab: Retrieval-Augmented Generation (RAGs)</h1>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ3FsdzRveTBrenMxM3VnbDMwaTJxN2NnZm50aGFibXk1NzNnY2Q0MCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LR5ZBwZHv02lmpVoEU/giphy.gif" alt="NLP Gif" style="width: 300px; height: 150px; object-fit: cover; object-position: center;">
# </div>

# %% [markdown]
# <h1 style="color: #FF6347;">Data Storage & Retrieval</h1>

# %% [markdown]
# <h2 style="color: #FF8C00;">PyPDFLoader</h2>
#
# `PyPDFLoader` is a lightweight Python library designed to streamline the process of loading and parsing PDF documents for text processing tasks. It is particularly useful in Retrieval-Augmented Generation workflows where text extraction from PDFs is required.
#
# - **What Does PyPDFLoader Do?**
#   - Extracts text from PDF files, retaining formatting and layout.
#   - Simplifies the preprocessing of document-based datasets.
#   - Supports efficient and scalable loading of large PDF collections.
#
# - **Key Features:**
#   - Compatible with popular NLP libraries and frameworks.
#   - Handles multi-page PDFs and embedded images (e.g., OCR-compatible setups).
#   - Provides flexible configurations for structured text extraction.
#
# - **Use Cases:**
#   - Preparing PDF documents for retrieval-based systems in RAGs.
#   - Automating the text extraction pipeline for document analysis.
#   - Creating datasets from academic papers, technical manuals, and reports.

# %%
#pip install langchain langchain_community pypdf
#pip install termcolor langchain_openai langchain-huggingface sentence-transformers chromadb langchain_chroma tiktoken openai python-dotenv
#!pip install -U langchain langchain-community

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h3 style="color: #FF8C00;">Loading the Documents</h3>

# %%
# FILE PATH FOR THE DOCUMENT
file_path = "../ai-for-everyone.pdf"

# %% [markdown]
# <h3 style="color: #FF8C00;">Documents into pages</h3>
#
# The `PyPDFLoader` library allows efficient loading and splitting of PDF documents into smaller, manageable parts for NLP tasks.
#
# This functionality is particularly useful in workflows requiring granular text processing, such as Retrieval-Augmented Generation (RAG).

# %%
# LOAD AND SPLIT THE DOCUMENT
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
len(pages)
# Out:
# 297

# %% [markdown]
# <h3 style="color: #FF8C00;">Pages into Chunks</h3>
#
#
# ####  RecursiveCharacterTextSplitter in LangChain
#
# The `RecursiveCharacterTextSplitter` is the **recommended splitter** in LangChain when you want to break down long documents into smaller, semantically meaningful chunks — especially useful in **RAG pipelines**, where clean context chunks lead to better LLM responses.
#
# ####  Parameters
#
# | Parameter       | Description                                                                 |
# |-----------------|-----------------------------------------------------------------------------|
# | `chunk_size`    | The **maximum number of characters** allowed in a chunk (e.g., `1000`).     |
# | `chunk_overlap` | The number of **overlapping characters** between consecutive chunks (e.g., `200`). This helps preserve context continuity. |
#
# ####  How it works
# `RecursiveCharacterTextSplitter` attempts to split the text **intelligently**, trying the following separators in order:
# 1. Paragraphs (`"\n\n"`)
# 2. Lines (`"\n"`)
# 3. Sentences or words (`" "`)
# 4. Individual characters (as a last resort)
#
# This makes it ideal for handling **natural language documents**, such as PDFs, articles, or long reports, without breaking sentences or paragraphs in awkward ways.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(pages)
len(chunks)
# Out:
# 1096

# %%
print(chunks[10:11])
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 16.0', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'creationdate': '2021-09-01T15:24:38+05:30', 'author': 'Pieter Verdegem', 'moddate': '2021-09-14T17:31:25-04:00', 'title': 'AI for Everyone?: Critical Perspectives', 'trapped': '/False', 'source': '../ai-for-everyone.pdf', 'total_pages': 310, 'page': 6, 'page_label': 'vi'}, page_content='Published By\nUniversity of Westminster Press\n115 New Cavendish Street\nLondon W1W 6UW\nwww.uwestminsterpress.co.uk\nIntroduction and Editorial Arrangement © Pieter Verdegem 2021\nText of Chapters © Several Contributors 2021\nFirst published 2021\nCover design: www.ketchup-productions.co.uk  \nSeries cover concept: Mina Bach (minabach.co.uk)\nPrint and digital versions typeset by Siliconchips Services Ltd. \nISBN (Paperback): 978-1-914386-16-9\nISBN (PDF): 978-1-914386-13-8\nISBN (EPUB): 978-1-914386-14-5\nISBN (Kindle): 978-914386-15-2\nDOI: https://doi.org/10.16997/book55\nThis work is licensed under the Creative Commons  \nAttribution-NonCommercial-NoDerivatives 4.0 International License.  \nTo view a copy of this license, visit http://creativecommons.org/licenses/by-nc \n-nd/4.0/ or send a letter to Creative Commons, 444 Castro Street, Suite 900,  \nMountain View, California, 94041, USA. This license allows for copying  \nand distributing the work, providing author attribution is clearly stated,')]

# %% [markdown]
# ####  Alternative: CharacterTextSplitter
#
# `CharacterTextSplitter` is a simpler splitter that breaks text into chunks based **purely on character count**, without trying to preserve any natural language structure.
#
# ##### Example:
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# text_splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
# ````
#
# This method is faster and more predictable but may split text in the middle of a sentence or paragraph, which can hurt performance in downstream tasks like retrieval or QA.
#
# ---
#
# #### Comparison Table
#
# | Feature                        | RecursiveCharacterTextSplitter | CharacterTextSplitter     |
# | ------------------------------ | ------------------------------ | ------------------------- |
# | Structure-aware splitting      |  Yes                          |  No                      |
# | Preserves sentence/paragraphs  |  Yes                          |  No                      |
# | Risk of splitting mid-sentence |  Minimal                     |  High                   |
# | Ideal for RAG/document QA      |  Highly recommended           |  Only if structured text |
# | Performance speed              |  Slightly slower             |  Faster                  |
#
# ---
#
# #### Recommendation
#
# Use `RecursiveCharacterTextSplitter` for most real-world document processing tasks, especially when building RAG pipelines or working with structured natural language content like PDFs or articles.

# %% [markdown]
# ## Best Practices for Choosing Chunk Size in RAG
#
# ### Best Practices for Chunk Size in RAG
#
# | Factor                      | Recommendation                                                                                                                                                                                          |
# | ---------------------------| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **LLM context limit**       | Choose a chunk size that lets you retrieve multiple chunks **without exceeding the model’s token limit**. For example, GPT-4o supports 128k tokens, but with GPT-3.5 (16k) or GPT-4 (32k), keep it modest. |
# | **Chunk size (in characters)** | Typically: **500–1,000 characters** per chunk → ~75–200 tokens. This fits well for retrieval + prompt without context overflow.                                                                           |
# | **Chunk size (in tokens)**  | If using token-based splitter (e.g. `TokenTextSplitter`): aim for **100–300 tokens** per chunk.                                                                                                            |
# | **Chunk overlap**           | Use **overlap of 10–30%** (e.g., 100–300 characters or ~50 tokens) to preserve context across chunk boundaries and avoid cutting off important ideas mid-sentence.                                        |
# | **Document structure**      | Use **`RecursiveCharacterTextSplitter`** to preserve semantic boundaries (paragraphs, sentences) instead of arbitrary cuts.                                                                                |
# | **Task type**               | For **question answering**, smaller chunks (~500–800 chars) reduce noise.<br>For **summarization**, slightly larger chunks (~1000–1500) are OK.                                                          |
# | **Embedding model**         | Some models (e.g., `text-embedding-3-large`) can handle long input. But still, smaller chunks give **finer-grained retrieval**, which improves relevance.                                                  |
# | **Query type**              | If users ask **very specific questions**, small focused chunks are better. For broader queries, bigger chunks might help.                                                                                  |
#
#
# ### Rule of Thumb
#
# | Use Case                 | Chunk Size      | Overlap |
# | ------------------------| --------------- | ------- |
# | Factual Q&A              | 500–800 chars   | 100–200 |
# | Summarization            | 1000–1500 chars | 200–300 |
# | Technical documents      | 400–700 chars   | 100–200 |
# | Long reports/books       | 800–1200 chars  | 200–300 |
# | Small LLMs (≤16k tokens) | ≤800 chars      | 100–200 |
#
#
# ### Avoid
#
# - Chunks >2000 characters: risks context overflow.
# - No overlap: may lose key information between chunks.

# %% [markdown]
# <h2 style="color: #FF8C00;">Embeddings</h2>
#
# Embeddings transform text into dense vector representations, capturing semantic meaning and contextual relationships. They are essential for efficient document retrieval and similarity analysis.
#
# - **What are OpenAI Embeddings?**
#   - Pre-trained embeddings like `text-embedding-3-large` generate high-quality vector representations for text.
#   - Encapsulate semantic relationships in the text, enabling robust NLP applications.
#
# - **Key Features of `text-embedding-3-large`:**
#   - Large-scale embedding model optimized for accuracy and versatility.
#   - Handles diverse NLP tasks, including retrieval, classification, and clustering.
#   - Ideal for applications with high-performance requirements.
#
# - **Benefits:**
#   - Reduces the need for extensive custom training.
#   - Provides state-of-the-art performance in retrieval-augmented systems.
#   - Compatible with RAGs to create powerful context-aware models.

# %%
from langchain_community.embeddings import OpenAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path = "../../.env")
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# <h2 style="color: #FF8C00;">ChromaDB</h2>
#
# ChromaDB is a versatile vector database designed for efficiently storing and retrieving embeddings. It integrates seamlessly with embedding models to enable high-performance similarity search and context-based retrieval.
#
# ### Workflow Overview:
# - **Step 1:** Generate embeddings using a pre-trained model (e.g., OpenAI's `text-embedding-3-large`).
# - **Step 2:** Store the embeddings in ChromaDB for efficient retrieval and similarity calculations.
# - **Step 3:** Use the stored embeddings to perform searches, matching, or context-based retrieval.
#
# ### Key Features of ChromaDB:
# - **Scalability:** Handles large-scale datasets with optimized indexing and search capabilities.
# - **Speed:** Provides fast and accurate retrieval of embeddings for real-time applications.
# - **Integration:** Supports integration with popular frameworks and libraries for embedding generation.

# %%
from langchain_chroma import Chroma

# %%
db = Chroma.from_documents(chunks, embeddings, persist_directory="/chroma_db_LAB")
print("ChromaDB created with document embeddings.")
# Out:
# ChromaDB created with document embeddings.

# %% [markdown]
# <h1 style="color: #FF6347;">Retrieving Documents</h1>

# %% [markdown]
# ### Exercice1: Write a user question that someone might ask about your book’s topic or content.

# %%
user_question = ["1. What are the main ways AI can be used in a business?", 
                 "2. How can AI create value in a business?",
                 "3. What are the main differences between AI and traditional software?",
                 "4. What skills does a non-technical person need to work with AI?",
                 "5. How should a company start building an AI strategy?",
                 "6. What are the most common misconceptions about artificial intelligence?",
                 "7. How can AI improve decision-making inside an organization?",
                 "8. What are the ethical risks associated with deploying AI systems?",
                 "9. How does machine learning differ from rule-based systems?",
                 "10. What types of business problems are best suited for AI solutions?",
                 "11. How should teams collaborate when building AI projects?"] # User question

results = []  # to store the results for each question

for question in user_question:
    retrieved_docs = db.similarity_search(question, k=10) # k is the number of documents to retrieve
    results.append(retrieved_docs)

# %%
results[0]
# Out:
# [Document(id='9e40f675-4859-424f-b615-7377f415706b', metadata={'creationdate': '2021-09-01T15:24:38+05:30', 'title': 'AI for Everyone?: Critical Perspectives', 'moddate': '2021-09-14T17:31:25-04:00', 'author': 'Pieter Verdegem', 'producer': 'Adobe PDF Library 16.0', 'page_label': '23', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'source': '../ai-for-everyone.pdf', 'page': 31, 'total_pages': 310, 'trapped': '/False'}, page_content='or cybernetics).\nArtificial intelligence can be classified into three types of systems: analyti -\ncal, human-inspired and humanised (Kaplan and Haenlein 2019). Analytical \nAI contains characteristics consistent with cognitive intelligence only: gener -\nating cognitive representation of the world and using learning based on past \nexperience to inform future decisions. Human-inspired AI contains elements \nof cognitive and emotional intelligence: understanding human emotions, \nin addition to cognitive elements, and considering them in their decision-  \nmaking. Humanised AI contains characteristics of all types of competencies \n(i.e., cognitive, emotional and social intelligence), is able to be self-conscious, \nand is self-aware in interactions with others.\nA robot driven by analytical artificial intelligence would be capable of \nanswering queries concerning restaurant recommendations based on certain'),
#  Document(id='3e7761f8-3cd9-4fab-a6d1-95241bfb23cb', metadata={'total_pages': 310, 'moddate': '2021-09-14T17:31:25-04:00', 'producer': 'Adobe PDF Library 16.0', 'trapped': '/False', 'creationdate': '2021-09-01T15:24:38+05:30', 'page': 35, 'page_label': '27', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'title': 'AI for Everyone?: Critical Perspectives', 'author': 'Pieter Verdegem', 'source': '../ai-for-everyone.pdf'}, page_content='used for other tasks within the job, and does not necessarily lead to a human \nbeing’s replacement. The Swedish bank, SEB, e.g., developed AIDA, an AI-\ndriven virtual assistant responding to a vast range of customers’ queries, such \nas how to make overseas payments or how to proceed when opening a bank \naccount. AIDA is even capable of detecting a customer’s mood by the tone of \nher or his voice and adapting its recommendations and suggestions thereto. In \naround 30% of situations, AIDA is not able to respond or help. In this case, the \ncustomer is transferred to a human. AIDA ’s implementation freed up human \nemployees’ time, which they then use for more complex demands, i.e., the 30% \nthat exceeded AIDA ’s limitations.\nA study by Wilson and Daugherty (2018, 117) suggested that it is in com -\npanies’ interest not to replace employees with AI, as this would not be a long-\nterm strategy. Looking at 1,500 corporations, they identified the best improve-'),
#  Document(id='0023a31a-79e9-4338-9305-96610e585bd5', metadata={'trapped': '/False', 'author': 'Pieter Verdegem', 'page': 132, 'page_label': '124', 'title': 'AI for Everyone?: Critical Perspectives', 'creationdate': '2021-09-01T15:24:38+05:30', 'total_pages': 310, 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'moddate': '2021-09-14T17:31:25-04:00', 'source': '../ai-for-everyone.pdf', 'producer': 'Adobe PDF Library 16.0'}, page_content='purpose technology comparable to the combustion engine. While this remains \nto be seen, AI has found diverse applications from recommendation engines \nand targeted advertising to predictive policing software, predictive mainte -\nnance, customer resource management and fraud detection. Capital became \nvisibly interested in machine learning around 2015. All the biggest tech com -\npanies in the world have since shifted to AI-intensive directions, including'),
#  Document(id='0c267b8e-851c-4b6c-8632-a59e99631078', metadata={'source': '../ai-for-everyone.pdf', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'total_pages': 310, 'page_label': '23', 'creationdate': '2021-09-01T15:24:38+05:30', 'moddate': '2021-09-14T17:31:25-04:00', 'page': 31, 'author': 'Pieter Verdegem', 'trapped': '/False', 'producer': 'Adobe PDF Library 16.0', 'title': 'AI for Everyone?: Critical Perspectives'}, page_content='and exchange data.\nMachine learning, simply put, is ‘methods that help computers learn without \nbeing explicitly programmed’ (Kaplan and Haenlein 2019, 17), and is applied \nin order to identify underlying patterns within the big data, and as such is an \nessential element of artificial intelligence. A more elaborated definition comes \nfrom Mitchell (1997, 2) stating ‘ A computer program is said to learn from \nexperience E with respect to some class of tasks T and performance measure P  \nif its performance at tasks in T, as measured by P, improves with experience E.’   \nAI is much broader than machine learning, as it additionally comprises such \nabilities as the perception of data (e.g., voice/image recognition, natural lan -\nguage processing, etc.) or the control and movement of objects (robotics  \nor cybernetics).\nArtificial intelligence can be classified into three types of systems: analyti -\ncal, human-inspired and humanised (Kaplan and Haenlein 2019). Analytical'),
#  Document(id='b5105e71-ede6-4cc9-9e16-688896eebaa4', metadata={'creationdate': '2021-09-01T15:24:38+05:30', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'source': '../ai-for-everyone.pdf', 'author': 'Pieter Verdegem', 'total_pages': 310, 'trapped': '/False', 'producer': 'Adobe PDF Library 16.0', 'title': 'AI for Everyone?: Critical Perspectives', 'moddate': '2021-09-14T17:31:25-04:00', 'page_label': '138', 'page': 146}, page_content='https://openai.com/blog/microsoft\nBroussard, M. 2018. Artificial Unintelligence: How Computers Misunderstand \nthe World. Cambridge, MA: MIT Press.\nBrynjolfsson, E. and McAfee, A. 2017. The Business of Artificial Intelligence. \nJuly. Harvard Business Review. Last accessed 10 May 2020: https://hbr.org \n/cover-story/2017/07/the-business-of-artificial-intelligence\nBurgess, A. 2018. The Executive Guide to Artificial Intelligence: How to Identify \nand Implement Applications for AI in your Organization. London: Palgrave \nMacmillan.\nCastelvecchi, D. 2016. Can we Open the Black Box of AI? 5 October. Nature News \n& Comment . Last accessed 15 May 2020: https://www.nature.com/news \n/can-we-open-the-black-box-of-ai-1.20731\xa0\nCockshott, P . 1988. Application of Artificial Intelligence Techniques to Eco -\nnomic Planning. University of Strathclyde. Last accessed 5 May 2020: http://\nwww.dcs.gla.ac.uk/~wpc/reports/plan_with_AIT.pdf'),
#  Document(id='52b7c77c-12e0-4259-8da8-379dee3ae114', metadata={'source': '../ai-for-everyone.pdf', 'author': 'Pieter Verdegem', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'trapped': '/False', 'producer': 'Adobe PDF Library 16.0', 'moddate': '2021-09-14T17:31:25-04:00', 'total_pages': 310, 'title': 'AI for Everyone?: Critical Perspectives', 'page': 32, 'creationdate': '2021-09-01T15:24:38+05:30', 'page_label': '24'}, page_content='24 AI for Everyone?\nobjective characteristics. Human-inspired AI robots could additionally read a \nhuman’s emotional state via facial recognition or tone of voice, and adapt its \nsuggestions, e.g., a human who appears sad or depressed would not enjoy a res-\ntaurant with a lively atmosphere, whereas a happy human might totally enjoy \nsuch an environment. Finally, a humanised robot would understand when it \nwas appropriate for it to offer to accompany the human or whenever this would \nnot be appreciated, e.g., a couple insanely in love who would rather spend the \ntime in intimate togetherness.\nFinally, we must distinguish AI on the lower spectrum from so-called expert \nsystems, often wrongly associated with artificial intelligence, as well as on \nthe higher spectrum from skills that remain only possible for human beings: \nExpert systems are ‘collections of rules programmed by humans in the form \nof if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems'),
#  Document(id='b00948e2-15b0-4ccd-bd6d-54b3f96be1bb', metadata={'producer': 'Adobe PDF Library 16.0', 'page': 132, 'creationdate': '2021-09-01T15:24:38+05:30', 'moddate': '2021-09-14T17:31:25-04:00', 'page_label': '124', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'author': 'Pieter Verdegem', 'title': 'AI for Everyone?: Critical Perspectives', 'source': '../ai-for-everyone.pdf', 'trapped': '/False', 'total_pages': 310}, page_content='by a different approach to AI known as machine learning. Machine learning is \noften anthropomorphised, but it is at base the use of statistical methods, called \nlearning algorithms, to find patterns in large datasets. On the basis of these pat-\nterns an algorithm called a ‘model’ is produced which may be used to analyse \nnew data (Alpaydin 2014, 2–3). A model thus represents ‘knowledge’ of the pat-\nterns found by the learning algorithm and can be used to make useful analyses \nor predictions. Much of the hype around machine learning derives from this \nautomated production of models from data, which Domingos (2015) calls the \n‘inverse of programming’ (6–7). \nMachine learning is being applied almost anywhere electronic data is accessi-\nble. Brynjolfsson and McAfee (2017) argue that machine learning is a general-\npurpose technology comparable to the combustion engine. While this remains \nto be seen, AI has found diverse applications from recommendation engines'),
#  Document(id='11887153-912a-469b-bc2c-e540e9be0dac', metadata={'trapped': '/False', 'total_pages': 310, 'source': '../ai-for-everyone.pdf', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'title': 'AI for Everyone?: Critical Perspectives', 'moddate': '2021-09-14T17:31:25-04:00', 'author': 'Pieter Verdegem', 'creationdate': '2021-09-01T15:24:38+05:30', 'page': 98, 'producer': 'Adobe PDF Library 16.0', 'page_label': '90'}, page_content='The Case of Artificial Intelligence\nFor some years now, technical solutions utilising artificial intelligence are \nwidely seen as means to tackle many fundamental problems of mankind. From \nfighting the climate crisis, tackling the problems of ageing societies, reducing \nglobal poverty, stopping terror, detecting copyright infringements or curing \ncancer to improving evidence-based politics, improving predictive police work, \nlocal transportation, self-driving cars and even waste removal.\nDefinitions\nThe first step towards a meaningful discussion about AI would be to define \nwhat exactly one means when talking about AI. Historically there have been \ntwo major understandings of AI: strong AI or Artificial General Intelligence \n(AGI) and weak AI or Artificial Narrow Intelligence (ANI). The goal of AGI is \nthe creation of an artificial human like intelligence, so an AI system with true \nhuman-like intelligence including perception, agency, consciousness, inten -'),
#  Document(id='bd882d46-532f-454b-add2-bb59f8e0a62c', metadata={'trapped': '/False', 'producer': 'Adobe PDF Library 16.0', 'title': 'AI for Everyone?: Critical Perspectives', 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'page': 162, 'source': '../ai-for-everyone.pdf', 'author': 'Pieter Verdegem', 'creationdate': '2021-09-01T15:24:38+05:30', 'page_label': '154', 'moddate': '2021-09-14T17:31:25-04:00', 'total_pages': 310}, page_content='behaviour by analysing their environment and taking actions – with \nsome degree of autonomy – to achieve specific goals. AI-based systems \ncan be purely software-based, acting in the virtual world (e.g. voice  \nassistants, image analysis, software, search engines, speech and face \nrecognition systems) or AI can be embedded in hardware devices  \n(e.g. advanced robots, autonomous cars, drones or Internet of Things \napplications). (European Commission 2018a, 2)\nMoreover, what emerges from the EU documents is the underlying assumption \nthat artificial intelligence will outperform human capabilities. In several docu-\nments, the EC explains that AI has the capacity to transform ‘our world’ , our \n‘society’ , our ‘work’ (The Communication, European Commission 2018b, 1),  \nthus implying that its abilities will exceed human cognitive functions. Take for \nexample this statement: \nAI needs vast amounts of data to be developed. Machine learning, a type'),
#  Document(id='a8112551-3851-4833-8161-1d4ae6e1bc00', metadata={'source': '../ai-for-everyone.pdf', 'total_pages': 310, 'creator': 'Adobe InDesign 16.4 (Macintosh)', 'producer': 'Adobe PDF Library 16.0', 'moddate': '2021-09-14T17:31:25-04:00', 'creationdate': '2021-09-01T15:24:38+05:30', 'author': 'Pieter Verdegem', 'trapped': '/False', 'page_label': '26', 'title': 'AI for Everyone?: Critical Perspectives', 'page': 34}, page_content='redundant. As such, in our above example, the individual would not need to \nprepare for work anymore, as this could be done entirely by the ASI-powered \nmachine or robot (Kaplan and Haenlein 2019). For a detailed discussion on the \nevolution of AI systems, we refer to Huang and Rust (2018).\nArtificial Intelligence: Machines and Humans\nIn the future, artificial intelligence will raise several challenges, and humans \nwill have to learn to coexist with machines and robots. Pushed by the global \nCOVID-19 health crisis, it is clear that AI will deeply impact societies around \nthe world (Kaplan 2021). We will discuss some of these questions, looking at \nchallenges in terms of algorithms and individual organisations; the employ -\nment market; and last but not least, democracy and human freedom potentially \nat stake due to advances in AI.\nAbout Algorithms and Organisations\nWhen machines and humans coexist, it is important that both do what they are')]

# %%
len(results)
# Out:
# 11

# %%
# DISPLAY TOP RESULTS
for i, docs in enumerate(results) :
    print(f"\n=== QUESTION {i+1} ===")
    # Normalise the structure: always a list
    #docs_list = docs if isinstance(docs, list) else [docs]
    for j, item in enumerate(docs[:3]) :
        # If item is a tuple → the Document is item[0]
        #doc = item[0] if isinstance(item, tuple) else item
        print(f"\nDOCUMENT {j+1} : \n{item.page_content[36:1000]}\n")
# Out:
# === QUESTION 1 ===
#
# DOCUMENT 1 :
# ence can be classified into three types of systems: analyti -
# cal, human-inspired and humanised (Kaplan and Haenlein 2019). Analytical
# AI contains characteristics consistent with cognitive intelligence only: gener -
# ating cognitive representation of the world and using learning based on past
# experience to inform future decisions. Human-inspired AI contains elements
# of cognitive and emotional intelligence: understanding human emotions,
# in addition to cognitive elements, and considering them in their decision-
# making. Humanised AI contains characteristics of all types of competencies
# (i.e., cognitive, emotional and social intelligence), is able to be self-conscious,
# and is self-aware in interactions with others.
# A robot driven by analytical artificial intelligence would be capable of
# answering queries concerning restaurant recommendations based on certain
#
#
# DOCUMENT 2 :
#  and does not necessarily lead to a human
# being’s replacement. The Swedish bank, SEB, e.g., developed AIDA, an AI-
# driven virtual assistant responding to a vast range of customers’ queries, such
# as how to make overseas payments or how to proceed when opening a bank
# account. AIDA is even capable of detecting a customer’s mood by the tone of
# her or his voice and adapting its recommendations and suggestions thereto. In
# around 30% of situations, AIDA is not able to respond or help. In this case, the
# customer is transferred to a human. AIDA ’s implementation freed up human
# employees’ time, which they then use for more complex demands, i.e., the 30%
# that exceeded AIDA ’s limitations.
# A study by Wilson and Daugherty (2018, 117) suggested that it is in com -
# panies’ interest not to replace employees with AI, as this would not be a long-
# term strategy. Looking at 1,500 corporations, they identified the best improve-
#
#
# DOCUMENT 3 :
#  combustion engine. While this remains
# to be seen, AI has found diverse applications from recommendation engines
# and targeted advertising to predictive policing software, predictive mainte -
# nance, customer resource management and fraud detection. Capital became
# visibly interested in machine learning around 2015. All the biggest tech com -
# panies in the world have since shifted to AI-intensive directions, including
#
#
# === QUESTION 2 ===
#
# DOCUMENT 1 :
#  and does not necessarily lead to a human
# being’s replacement. The Swedish bank, SEB, e.g., developed AIDA, an AI-
# driven virtual assistant responding to a vast range of customers’ queries, such
# as how to make overseas payments or how to proceed when opening a bank
# account. AIDA is even capable of detecting a customer’s mood by the tone of
# her or his voice and adapting its recommendations and suggestions thereto. In
# around 30% of situations, AIDA is not able to respond or help. In this case, the
# customer is transferred to a human. AIDA ’s implementation freed up human
# employees’ time, which they then use for more complex demands, i.e., the 30%
# that exceeded AIDA ’s limitations.
# A study by Wilson and Daugherty (2018, 117) suggested that it is in com -
# panies’ interest not to replace employees with AI, as this would not be a long-
# term strategy. Looking at 1,500 corporations, they identified the best improve-
#
#
# DOCUMENT 2 :
# n. This is generated by the producers of
# AI commodities – Microsoft’s online AI Business School and Google’s array
# of free AI education courses are two examples – but also by a wide variety of
# industry promoters, from consulting firms, see Accenture’s (n.d.) guide to ‘ AI
# for Business Transformation’ and management-oriented books like The Execu-
# tive Guide to Artificial Intelligence (Burgess 2018). Such sources can reveal what
# AI capitals are worried about and indicate potential bottlenecks amenable to
# outsider intervention. Once identified, bottlenecks can be analysed and the
# social relations which support valorisation via AI therein might be replaced
# with alternative social relations not amenable to the data-hungry valorisa -
# tion of AI capital. Finding bottlenecks returns us to the question of visibility,
# without which strategy cannot be formulated. I hope this chapter will contrib-
#
#
# DOCUMENT 3 :
# 1st century. (ibid. 2)
# The High-Level Expert Group on Artificial Intelligence (AI HLEG) goes into
# even greater detail about the capabilities of AI to make humanity ‘flourish’ , thus
# solving all problems of society.
# We believe that AI has the potential to significantly transform society. AI
# is not an end in itself, but rather a promising means to increase human
# flourishing, thereby enhancing individual and societal well-being and
# the common good, as well as bringing progress and innovation. In par-
# ticular, AI systems can help to facilitate the achievement of the UN’s
# Sustainable Development Goals, such as promoting gender balance
# and tackling climate change, rationalising our use of natural resources,
# enhancing our health, mobility and production processes, and support-
# ing how we monitor progress against sustainability and social cohesion
# indicators. (High-Level Expert Group 2019a, 4)
#
#
# === QUESTION 3 ===
#
# DOCUMENT 1 :
# ules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
# lack the ability to learn autonomously from external data, they should defi -
# nitely not be counted as AI. Expert systems reconstruct human intelligence in
# a top-down manner (also called the knowledge-based or symbolic approach),
# considering that it can be codified as a set of predefined rules. In contrast, AI
# applies a bottom-up approach (also called the behaviour-based or connection-
# ist approach) and imitates a brain’s set-up (e.g., through neural networks) by
# using large quantities of data to infer knowledge independently.
# The question that arises is what will remain human in the future and what
# cannot be imitated by AI systems, which is quite a tough question to answer.
# Most likely, humans will always have exclusivity when it comes to artistic crea-
#
#
# DOCUMENT 2 :
#  not as engineering artefacts, but as a class of actors with particu -
# lar behavioural patterns and ecology’ . A computer program that can learn
# goes beyond what it is programmed to do. The developments in the field (and
# the transformation of the definitions of AI) notwithstanding, the position of
# Turing, as well as that of Searle, are not totally overturned yet. Searle’s vague
# definition of Strong AI (to create intentionality artificially) has led to the term
# ‘weak AI’ , and both terms are still in use today (Morgan 2018). Weak AI deline-
# ates an artificial agent that succeeds to reach a goal in a given environment by
# computing a function from its sensory inputs to its actions. From chatbots we
# encounter on websites to a washing machine that can use sensors to calculate
# the washing load and adjust the water usage accordingly, all ‘smart’ applications
# and tools fall under weak AI. Strong AI, or artificial general intelligence (AGI),
#
#
# DOCUMENT 3 :
# ment and taking actions – with
# some degree of autonomy – to achieve specific goals. AI-based systems
# can be purely software-based, acting in the virtual world (e.g. voice
# assistants, image analysis, software, search engines, speech and face
# recognition systems) or AI can be embedded in hardware devices
# (e.g. advanced robots, autonomous cars, drones or Internet of Things
# applications). (European Commission 2018a, 2)
# Moreover, what emerges from the EU documents is the underlying assumption
# that artificial intelligence will outperform human capabilities. In several docu-
# ments, the EC explains that AI has the capacity to transform ‘our world’ , our
# ‘society’ , our ‘work’ (The Communication, European Commission 2018b, 1),
# thus implying that its abilities will exceed human cognitive functions. Take for
# example this statement:
# AI needs vast amounts of data to be developed. Machine learning, a type
#
#
# === QUESTION 4 ===
#
# DOCUMENT 1 :
# teristics. Human-inspired AI robots could additionally read a
# human’s emotional state via facial recognition or tone of voice, and adapt its
# suggestions, e.g., a human who appears sad or depressed would not enjoy a res-
# taurant with a lively atmosphere, whereas a happy human might totally enjoy
# such an environment. Finally, a humanised robot would understand when it
# was appropriate for it to offer to accompany the human or whenever this would
# not be appreciated, e.g., a couple insanely in love who would rather spend the
# time in intimate togetherness.
# Finally, we must distinguish AI on the lower spectrum from so-called expert
# systems, often wrongly associated with artificial intelligence, as well as on
# the higher spectrum from skills that remain only possible for human beings:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
#
#
# DOCUMENT 2 :
# e following capabilities:  natural language
# processing (being able to communicate successfully),  knowledge representation
# (being able to store what it knows or hears), automated reasoning (being able
# to use the stored information to answer questions and to draw new conclu -
# sions) and machine learning (being able to adapt to new circumstances and to
# detect and extrapolate patterns).
# Towards an Operational Definition – For Now
# It is helpful to first distinguish between strong and weak AI (Bostrom 2014).
# Strong AI, also called AGI (Artificial General Intelligence) refers to com -
# putational systems with general cognitive abilities which have the future
#
#
# DOCUMENT 3 :
# will need to coexist with machines. Jobs traditionally done by
# humans will be shifted towards AI systems. Artificial intelligence is already able
# to translate languages, diagnose illnesses, assist in retail (Kaplan 2020c), and
# the like – in several cases, better than the human workforce. Human jobs might
# be created in the future that are unimaginable now, similar to the fact that
# nobody really predicted the job of mobile app designers just a few years ago.
# In this world, AI would rather be augmenting and complementing – rather
# than replacing – humans in their work. In the pessimistic case, i.e., massive
# unemployment, ideas such as universal basic income are already being dis -
# cussed. Fundamental philosophical questions would need to be answered sur-
# rounding life for humans when most of our work is done by AI systems. In
# any case, the State will certainly have to come up with a set of rules govern -
#
#
# === QUESTION 5 ===
#
# DOCUMENT 1 :
# cks returns us to the question of visibility,
# without which strategy cannot be formulated. I hope this chapter will contrib-
# ute to an incremental increase in visibility and, perhaps, a half step towards
# a strategy.
# References
# Accenture. n.d. AI for Business Transformation. https://www.accenture.com/us
# -en/services/applied-intelligence/business-transformation
# Agarwal, D. 2019. Chat with Kevin Scott EVP and CTO of Microsoft. 15 July.
# Venture Beat. Last accessed 5 May 2020: https://www.youtube.com/watch?v
# =npXxiVaY9p0
# Alharby, M. and Van Moorsel, A. 2017. Blockchain-Based Smart Contracts: A
# Systematic Mapping Study. arXiv preprint arXiv:1710.06372.
# Alpaydin, E. 2014. Introduction to Machine Learning . Cambridge, MA: MIT
# Press.
# Amadeo, R. 2018. Google’s Iron Grip on Android: Controlling Open Source by
# Any Means Necessary. 21 August. Ars Technica. Last accessed 5 May 2020:
#
#
# DOCUMENT 2 :
#  benefit and the return on investment for
# their investors and shareholders?
# The AI4People initiative, set up by the non-profit organisation Atomium-
# EISMD (European Institute for Science, Media and Democracy), is the Euro -
# pean response to the Asilomar AI initiative. AI4People also brings together
# academics, business partners (e.g. Facebook, Intel and Microsoft), and civil
# society organisations. The ambition of AI4People (Atomium-EISMD, 2020) is
# ‘to draft a set of ethical guidelines aimed at facilitating the design of policies
# favourable to the development of a “Good AI Society”’ .
# AI4People has developed an ethical framework of principles that should
# underpin the adoption of AI and offers a list of specific recommendations
# and action points that should help to establish a Good AI Society  (Floridi
# et al. 2018). AI4People proposes five core ethical principles: (1) beneficence
#
#
# DOCUMENT 3 :
#  reflect the priorities of the stakeholders involved, ethi -
# cal guidelines project a vision of what type of AI is preferred, what benefits it
# should deliver and how we should deal with potential risks. Obviously, this is
# part of a normative debate but we can learn a lot from who is involved in these
# discussions and how they aim to shape the future of AI.
# Given the projections about the role of AI in economic development, AI is
# high on the policy agenda. Putin famously said that the nation that leads in AI
# would be the ruler of the world (Vincent 2017). Major nations are rushing to
# create AI initiatives, unsurprisingly led by China and the USA (Lee 2018). What
# is surprising, however, is how much overlap there is in their strategic vision.
# China’s national strategy for AI, the New Generation Artificial Intelligence
# Development Plan (NGAIDP), was released in 2017 (State Council of China
#
#
# === QUESTION 6 ===
#
# DOCUMENT 1 :
# AI
#
#
# DOCUMENT 2 :
# uman species (The Economist 2020b; Bostrom 2014). Stephen
# Hawking has pronounced to the BBC that ‘the development of full artificial
# intelligence could spell the end of the human race’ (Cellan-Jones 2014, n.p.).
# AI represents profound fears – culminating in our extinction – but also
# profound hopes in bettering life for humanity and life on Earth.
# For these reasons – to ward off our fears and harness AI for betterment –
# the need to continually push for deeper understanding of AI is also corre -
# spondingly clear. The current rationalisation of AI persists in human terms,
# as is evident from even the most recent musings on the limitations of AI (The
# Economist 2020a): comparisons are consistently made with human learning
# and cognition, such as ‘embodied cognition’ , or references to the ‘irredeemably
# complex’ nature of human minds (n.p.). In filling the gap of understanding why
#
#
# DOCUMENT 3 :
# erspectives on AI  5
# potential to surpass human intellectual capacities. This can be seen as the attempt
# to mechanise human-level intelligence. Computer scientists and philosophers
# disagree on whether this is at all possible (Coeckelbergh 2020): some directly
# reject this scenario while others think if theoretically possible, it is not likely to
# happen (soon) in practice (Boden 2016). This is why it might be better to focus
# on advancements in weak AI or ANI (Artificial Narrow Intelligence), as this is
# the type of AI already impacting everyday life on a massive scale. Weak/nar -
# row AI performs specific tasks which would normally require intelligence in a
# human being – machines aiding human thought and action. This type of AI is a
# mathematical method for prediction (Agrawal et al. 2018). Such systems can be
# extremely powerful but are limited in the range of tasks they can perform.
#
#
# === QUESTION 7 ===
#
# DOCUMENT 1 :
# t Algorithms and Organisations
# When machines and humans coexist, it is important that both do what they are
# good at. As an illustration, let’s have a look at a study by researchers from MIT’s
# Computer Science and Artificial Intelligence Laboratory in cooperation with
# the machine-learning startup PatternEx (Conner-Simons 2016). AI systems
# and humans scored far better in identifying cyber-attacks when collaborating
# than when trying to do so separately. While the AI systems could crawl through
# enormous quantities of big data, humans were better at detecting anomalies,
# playing those back into the system. This iterative and collaborative approach
# was optimal.
# Also, humans are better in behaving ethically and morally, while algorithms
# have problems doing so, as the notion of ethics and morals is difficult to pro -
# gram. Machines, however, are better at, e.g., utilitarian, repetitive tasks. While
#
#
# DOCUMENT 2 :
# umans and Machines Might Have to Coexist   27
# conscience, are more likely to be biased, essentially because the data on which
# they were trained was biased. A study by Wilson, Hoffman and Morgenstern
# (2020) illustrates that several decision-support systems applied by judges
# may be racially biased (as a result of past rulings); and self-driving cars better
# detected lighter skin than darker tones, since their algorithm was trained using
# pictures among which were few people of colour.
# Regulation and guidance is definitely needed in order to avoid such bias, to
# establish a good foundation for machine < > human collaboration. The devel -
# opment of specific requirements with respect to the testing and training of AI is
# likely the preferred approach, as opposed to regulating artificial intelligence
# itself. In addition, we could require AI warranties, consistent with safety test -
#
#
# DOCUMENT 3 :
# teristics. Human-inspired AI robots could additionally read a
# human’s emotional state via facial recognition or tone of voice, and adapt its
# suggestions, e.g., a human who appears sad or depressed would not enjoy a res-
# taurant with a lively atmosphere, whereas a happy human might totally enjoy
# such an environment. Finally, a humanised robot would understand when it
# was appropriate for it to offer to accompany the human or whenever this would
# not be appreciated, e.g., a couple insanely in love who would rather spend the
# time in intimate togetherness.
# Finally, we must distinguish AI on the lower spectrum from so-called expert
# systems, often wrongly associated with artificial intelligence, as well as on
# the higher spectrum from skills that remain only possible for human beings:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
#
#
# === QUESTION 8 ===
#
# DOCUMENT 1 :
# ous and problematic uses of the technol -
# ogy, which has prompted a global conversation on the normative principles
# to which AI ought adhere, under the banner of ‘ AI ethics’ . Governments, cor-
# porations and NGOs throughout the world have generated their own sets of
# AI ethics principles. Questions and critiques arise about the content of these
# ethics principles, whether they are actually implemented, and their (legal)
# enforceability (Wagner 2018). Broader issues emerge about the power and
# privilege of the organisations, governments and individuals which are creat -
# ing and implementing AI and accompanying ethical principles. For example,
# Google has recently announced an ethics service (Simonite 2020), yet has been
# mired in ethics controversies from violating privacy law (Finley 2019), work -
# ing on controversial military projects (Crofts and van Rijswijk 2020) and dis -
#
#
# DOCUMENT 2 :
#  we also see in the US, the mere fact of AI ethics principles hav-
# ing the binding force of law is insufficient to establish their ‘goodness’ .
# It is also insufficient to focus solely on social norms in the form of unen -
# forceable ethical principles as these can indeed result in ethics washing. We
# agree with Powles and Nissenbaum (2018) who see a focus on ‘solving’ issues
# of fairness, accountability and transparency as foremost among these discus -
# sions through code (and to some extent social norms) as problematic, and one
# which obscures the broader structural problems which are at the root of bias
# in machine learning. Again, Ihde’s critique of the ‘designer fallacy’ mentioned
# above also applies here regarding the unintended consequences of attempting
# to ‘design out’ bias and other problems in digital technologies. Furthermore,
# broader existential questions about whether a particular system or technol -
#
#
# DOCUMENT 3 :
# points to the ‘omissions’ from many AI ethics
# frameworks comprising ‘red lines’ on uses of AI which should be prohibited,
# political abuse of AI systems and the ‘“hidden” social and ecological costs’ of
# AI systems. Furthermore, ethical AI principles such as fairness, accountability,
# transparency judge only the information systems within which AI is installed,
# without stepping back to analyse the socio-economic and political realities of
# the organisations which own and use the data – as per Bigo et al. ’s (2019) data
# politics – and AI, and the people who willingly or ignorantly provide the fuel
# to power AI.
# The critique of AI ethics’ substance also extends to scenarios where AI eth -
# ics are backed by legal enforceability. While a latecomer to state-led AI ethics,
# the United States has made up for lost time since 2019 starting with the Trump
# Administration Executive Order on Maintaining American Leadership in Arti-
#
#
# === QUESTION 9 ===
#
# DOCUMENT 1 :
# Agrawal et al. 2018). Such systems can be
# extremely powerful but are limited in the range of tasks they can perform.
# Russell and Norvig (2016) see machine learning as a prerequisite for intel -
# ligent machines. Machine learning is a paradigm that allows programs to auto-
# matically improve their performance on a particular task by learning from vast
# amounts of data (Alpaydin 2016). It seeks and uses statistical patterns and cor-
# relation in enormous datasets. Unlike older types of AI (e.g. expert systems,
# that are based on rules which are inputted by humans), machine learning algo-
# rithms learn not from humans but from data. The availability of significant
# amounts of real-world data (that we produce by using the internet, social media,
# sensors or other Internet-of-Things applications), combined with the availabil-
# ity of powerful and almost limitless computing capacity and advancements in
#
#
# DOCUMENT 2 :
# as machine learning. Machine learning is
# often anthropomorphised, but it is at base the use of statistical methods, called
# learning algorithms, to find patterns in large datasets. On the basis of these pat-
# terns an algorithm called a ‘model’ is produced which may be used to analyse
# new data (Alpaydin 2014, 2–3). A model thus represents ‘knowledge’ of the pat-
# terns found by the learning algorithm and can be used to make useful analyses
# or predictions. Much of the hype around machine learning derives from this
# automated production of models from data, which Domingos (2015) calls the
# ‘inverse of programming’ (6–7).
# Machine learning is being applied almost anywhere electronic data is accessi-
# ble. Brynjolfsson and McAfee (2017) argue that machine learning is a general-
# purpose technology comparable to the combustion engine. While this remains
# to be seen, AI has found diverse applications from recommendation engines
#
#
# DOCUMENT 3 :
# odelling: instead of trying to simulate the
# inner workings of a system, it’s a transferable method of number crunching that
# simply requires sufficiently large amounts of training data. It’s also different
# to traditional statistics, although it branches off from that family tree – where
# statistics tries to assess very precisely the relationships between variables and
# the robustness and possible error in the parameters, machine learning really
# doesn’t care – its only goal is to make repeatable predictions. Whereas sta -
# tistics is realist (in trying to model an underlying truth), machine learning
# is instrumentalist.
# These may seem like nerdy distinctions but they have major consequences
# when it comes to social impacts, not least because of the inherited aura of infal-
# libility that machine learning inherits from its associations with science and
# statistics. Like them, it’s an approach that elevates quantitative analysis over
#
#
# === QUESTION 10 ===
#
# DOCUMENT 1 :
# teristics. Human-inspired AI robots could additionally read a
# human’s emotional state via facial recognition or tone of voice, and adapt its
# suggestions, e.g., a human who appears sad or depressed would not enjoy a res-
# taurant with a lively atmosphere, whereas a happy human might totally enjoy
# such an environment. Finally, a humanised robot would understand when it
# was appropriate for it to offer to accompany the human or whenever this would
# not be appreciated, e.g., a couple insanely in love who would rather spend the
# time in intimate togetherness.
# Finally, we must distinguish AI on the lower spectrum from so-called expert
# systems, often wrongly associated with artificial intelligence, as well as on
# the higher spectrum from skills that remain only possible for human beings:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
#
#
# DOCUMENT 2 :
#  combustion engine. While this remains
# to be seen, AI has found diverse applications from recommendation engines
# and targeted advertising to predictive policing software, predictive mainte -
# nance, customer resource management and fraud detection. Capital became
# visibly interested in machine learning around 2015. All the biggest tech com -
# panies in the world have since shifted to AI-intensive directions, including
#
#
# DOCUMENT 3 :
# ence can be classified into three types of systems: analyti -
# cal, human-inspired and humanised (Kaplan and Haenlein 2019). Analytical
# AI contains characteristics consistent with cognitive intelligence only: gener -
# ating cognitive representation of the world and using learning based on past
# experience to inform future decisions. Human-inspired AI contains elements
# of cognitive and emotional intelligence: understanding human emotions,
# in addition to cognitive elements, and considering them in their decision-
# making. Humanised AI contains characteristics of all types of competencies
# (i.e., cognitive, emotional and social intelligence), is able to be self-conscious,
# and is self-aware in interactions with others.
# A robot driven by analytical artificial intelligence would be capable of
# answering queries concerning restaurant recommendations based on certain
#
#
# === QUESTION 11 ===
#
# DOCUMENT 1 :
# will be needed to address the various challenges with regards to
# the development of artificial intelligence. Which formal method can be used
# to test for algorithmic bias? Can we identify simple to use measures to assess
# bias, similar to the way we assess reliability and validity? What is the best way to
# bridge (deep) learning and privacy? Should learning be conducted on the user
# side (with algorithms requiring new data)? Or should data be transferred to a
# trusted intermediary who performs the analysis on behalf of firms? Do users
# need to be compensated in one way or another for data or resources provided?
# Moreover, how can the refusal to share data lead to biases in the data available
# for learning? Which data sources can and should be used for algorithmic learn-
# ing? Are there certain types of data that should be ‘off-limits’? What role will
# interdisciplinary AI teams play in establishing coexistence between humans
#
#
# DOCUMENT 2 :
# ity
# Good Data must be orchestrated and mediated by and for individuals and col-
# lectives. Individuals and collectives should have access to, control over and
# opportunities to use their own data to promote sustainable, communal liv -
# ing, including communal sharing for community decision-making and self-
# governance and self-determination (see Lovett et al. 2019; Ho and Chuang
# 2019). Data collection, analysis and use must be orchestrated and mediated by
# and for data subjects and communities advancing their data and technological
# sovereignty, rather than determined by those in power (Kuch et al. 2019; Mann
# et al. 2020). AI, constructed by communities, should be designed to assist com-
# munity participation in data-related decision-making and governance. This
# community element is usually absent from AI ethics initiatives, both in their
# formation – principally by elites – and their content. Commitment to theories
#
#
# DOCUMENT 3 :
#  need is still a bespoke and expensive business. The complexity
# of AI in addition to its cost is why AI production is dominated by three kinds
# of enterprise: (a) technical startups, (b) medium to large sized corporations
# and (c) governments. There is comparatively very little AI constructed by low-
# resource community groups, non-profits, aid agencies, advocacy groups for the
# marginalised and disenfranchised.
# What, then, can be done to address these barriers? A multipronged approach
# is necessary to (start to) dismantle (some of) them, with a recognition of the
# limits of law, code, markets and social norms (as per Lessig’s (1999) modes
# of regulation) as tools through which Good Data can be achieved. Central
# though to the problem is the political economy of data in the context of neo -
# liberal capitalism. Both governments and corporations have a strong, in some
# cases existential, interest in gathering, analysing and using data. Truly curbing

# %% [markdown]
# <h2 style="color: #FF8C00;">Preparing Content for GenAI</h2>

# %%
def _get_document_prompt(docs):
    prompt = "\n"

    # Always normalise to a list
    #docs_list = docs if isinstance(docs, list) else [docs]

    for item in docs:

        # If item is a tuple → the Document is item[0]
        # doc = item[0] if isinstance(item, tuple) else item

        # Securing access to content
        content = getattr(item, "page_content", "")

        prompt += "\nCONTENT:\n"
        prompt += content + "\n\n"

    return prompt

# %%
# GENERATE A FORMATTED CONTEXT FROM THE RETRIEVED DOCUMENTS
formatted_contexts = []

for docs in results:
    formatted_contexts.append(_get_document_prompt(docs))

print("CONTEXTS FORMATTED FOR GPT MODEL.")
# Out:
# CONTEXTS FORMATTED FOR GPT MODEL.

# %% [markdown]
# <h2 style="color: #FF8C00;">ChatBot Architecture</h2>

# %% [markdown]
# ### Exercice2: Write a prompt that is relevant and tailored to the content and style of your book.

# %%
prompts = []

for question, context in zip(user_question, formatted_contexts):

    prompt = f"""
You are an AI assistant helping a business leader understand artificial intelligence.
Using only the information from the retrieved context, explain the answer in a clear,
non-technical, and practical way. Focus on business impact, strategy, and real-world
examples. If the context does not contain enough information, say so explicitly.

User question:
{question}

Context:
{context}

Answer:
"""
    prompts.append(prompt)

# %%
import openai

# %% [markdown]
# ### Exercice3: Tune parameters like temperature, and penalties to control how creative, focused, or varied the model's responses are.

# %%
# SET UP GPT CLIENT AND PARAMETERS
client = openai.OpenAI()

model_params = {
    "model" : "gpt-4o",
    "temperature" : 0.2,       # LOW CREATIVITY => MORE FACTUAL AND GROUNDED
    "max_tokens" : 250,        # ALLOW FOR DETAILED ANSWERS
    "top_p" : 0.9,             # BALANCED NUCLEUS SAMPLING
    "frequency_penalty" : 0.2, # REDUCE REPETITION
    "presence_penalty" : 0.1   # SLIGHTLY ENCOURAGE NEW IDEAS
}

# %% [markdown]
# <h1 style="color: #FF6347;">Response</h1>

# %%
answers = []

for prompt in prompts :
    messages = [{"role" : "user", "content" : prompt}]
    completion = client.chat.completions.create(
        messages=messages,
        **model_params,
        timeout=120
    )
    answers.append(completion.choices[0].message.content)

# %%
for index, answer in enumerate(answers) :
    print(f"\n=== ANSWER TO QUESTION {index+1} ===\n")
    print(answer)

#answer = completion.choices[0].message.content
#print(answer)
# Out:
# === ANSWER TO QUESTION 1 ===
#
# The context provides several examples of how AI can be used in business, focusing on its practical applications and impact. Here are the main ways AI can be utilized:
#
# 1. **Customer Service Enhancement**: AI-driven virtual assistants, like SEB's AIDA, can handle a wide range of customer queries, such as making overseas payments or opening bank accounts. These systems can also detect customer emotions through voice tone and adapt their responses accordingly. This not only improves customer satisfaction but also frees up human employees to focus on more complex tasks.
#
# 2. **Recommendation Engines and Targeted Advertising**: AI can analyze customer data to provide personalized recommendations and targeted advertising, enhancing marketing strategies and increasing sales.
#
# 3. **Predictive Maintenance**: In industries like manufacturing, AI can predict equipment failures before they occur, reducing downtime and maintenance costs.
#
# 4. **Fraud Detection**: AI systems can analyze transaction patterns to detect fraudulent activities, helping businesses protect themselves from financial losses.
#
# 5. **Predictive Policing**: AI can be used in law enforcement to predict crime hotspots and allocate resources more effectively, although this application comes with ethical considerations.
#
# 6. **General-Purpose Technology**: AI is seen as a transformative technology comparable to the combustion engine, with potential
#
# === ANSWER TO QUESTION 2 ===
#
# AI can create value in a business by enhancing efficiency, improving customer service, and freeing up human employees to focus on more complex tasks. For instance, the Swedish bank SEB implemented an AI-driven virtual assistant named AIDA. This assistant handles a wide range of customer queries, such as making overseas payments or opening a bank account. AIDA can even detect a customer's mood through their voice tone and adjust its responses accordingly. In cases where AIDA cannot assist (about 30% of the time), the query is passed on to a human employee. This system allows human employees to concentrate on more complex issues that require human intervention.
#
# Moreover, AI is seen as a tool to augment and complement human work rather than replace it. This approach can lead to increased productivity and innovation within a company. For example, during the COVID-19 pandemic, AI played a crucial role in identifying potentially infected individuals and analyzing the virus, showcasing its potential to tackle complex global challenges.
#
# In summary, AI can create business value by automating routine tasks, enhancing customer interactions, and allowing human workers to focus on strategic and complex issues that drive business growth.
#
# === ANSWER TO QUESTION 3 ===
#
# The context provided does not explicitly outline the main differences between AI and traditional software. However, I can infer some distinctions based on the information available:
#
# 1. **Learning Capability**: Traditional software operates based on predefined rules and logic set by human programmers. It follows a top-down approach where every possible scenario is anticipated and coded in advance. In contrast, AI, particularly through machine learning, uses a bottom-up approach. It can learn from large amounts of data and improve its performance over time without being explicitly programmed for every possible situation.
#
# 2. **Adaptability**: AI systems have the ability to adapt to new situations by learning from data, which allows them to perform tasks they were not initially programmed for. Traditional software lacks this adaptability and requires manual updates to handle new scenarios.
#
# 3. **Autonomy**: AI systems can operate with some degree of autonomy, making decisions based on data analysis to achieve specific goals. Traditional software typically requires more direct human intervention to function effectively.
#
# 4. **Data Dependency**: AI relies heavily on vast amounts of data to learn and make decisions, whereas traditional software does not inherently require such data-driven learning processes.
#
# In terms of business impact, AI can transform operations by automating complex tasks, providing insights from data analysis
#
# === ANSWER TO QUESTION 4 ===
#
# The context provided does not contain specific information about the skills a non-technical person needs to work with AI. Therefore, I cannot provide an answer based on the given context.
#
# === ANSWER TO QUESTION 5 ===
#
# The context provided does not contain specific information on how a company should start building an AI strategy. It mentions various aspects of AI, such as ethical guidelines, data importance, and policy development, but does not directly address the steps or considerations for creating an AI strategy for a business. Therefore, I cannot provide a detailed answer based on the given context.
#
# === ANSWER TO QUESTION 6 ===
#
# The context provided does not contain explicit information about the most common misconceptions about artificial intelligence. Therefore, I cannot provide a detailed answer based on the given context. If you have more specific questions or need information on a different aspect of AI, feel free to ask!
#
# === ANSWER TO QUESTION 7 ===
#
# The context provides several insights into how AI can improve decision-making within an organization by highlighting the collaborative potential between humans and AI systems. Here are some key points:
#
# 1. **Collaboration Between Humans and AI**: AI systems excel at processing large volumes of data quickly and identifying patterns, while humans are better at understanding context, ethics, and anomalies. When these strengths are combined, as shown in a study by MIT's Computer Science and Artificial Intelligence Laboratory, the collaboration between AI and humans leads to better outcomes, such as more accurately identifying cyber-attacks.
#
# 2. **Efficiency and Focus**: AI can handle repetitive and data-intensive tasks, freeing up human employees to focus on more complex and strategic issues. For example, SEB bank's AI-driven virtual assistant, AIDA, handles routine customer queries, allowing human staff to concentrate on more challenging problems that require human judgment.
#
# 3. **Enhanced Decision-Making**: By leveraging AI's ability to analyze vast datasets and recognize patterns, organizations can make more informed decisions. This is particularly beneficial in areas like risk management, where AI can provide insights that might not be immediately apparent to human analysts.
#
# 4. **Improved Customer Interaction**: AI systems can adapt their responses based on customer emotions or preferences
#
# === ANSWER TO QUESTION 8 ===
#
# The context provides a broad overview of the ethical risks associated with deploying AI systems, focusing on several key areas:
#
# 1. **Bias and Fairness**: AI systems can inherit biases present in the data they are trained on. For example, decision-support systems used by judges may exhibit racial bias due to biased historical data. Similarly, facial recognition technologies have been criticized for failing to accurately identify individuals with darker skin tones. This can lead to unfair treatment and discrimination, which is a significant ethical concern for businesses deploying AI.
#
# 2. **Transparency and Accountability**: There is often a lack of transparency in how AI algorithms function, making it difficult to understand their decision-making processes. This opacity can lead to unintended consequences and makes it challenging to hold AI systems accountable for their actions.
#
# 3. **Privacy Concerns**: Violations of privacy laws have been a major issue, as seen in controversies involving companies like Google. The collection and use of personal data by AI systems raise significant ethical questions about user consent and data protection.
#
# 4. **Power Dynamics and Ethics Implementation**: The development and implementation of AI ethics principles are often influenced by powerful organizations, which may not always act in the public's best interest. There is skepticism about whether these principles are genuinely implemented
#
# === ANSWER TO QUESTION 9 ===
#
# Machine learning and rule-based systems are two different approaches to artificial intelligence, each with distinct characteristics and implications for business.
#
# Rule-based systems, also known as expert systems, operate on a set of predefined rules programmed by humans. These rules are typically structured as "if-then" statements. For example, a rule-based system in a customer service application might be programmed to respond with a specific answer if a customer asks a particular question. The main limitation of rule-based systems is that they cannot learn or adapt on their own; they require human intervention to update or expand the rules.
#
# In contrast, machine learning is a more dynamic approach where computers learn from data rather than being explicitly programmed with rules. Machine learning algorithms analyze large datasets to identify patterns and correlations. From these patterns, the algorithms create models that can make predictions or decisions based on new data. This ability to learn from data allows machine learning systems to improve over time without human intervention.
#
# The business impact of machine learning is significant because it enables companies to automate complex decision-making processes and improve efficiency. For example, machine learning can power recommendation engines that suggest products to customers based on their past behavior, leading to increased sales and customer satisfaction. It can also be used in predictive maintenance for machinery, reducing downtime
#
# === ANSWER TO QUESTION 10 ===
#
# The context provides some insights into the types of business problems that are well-suited for AI solutions. AI can be effectively applied to a variety of business challenges, particularly those involving large amounts of data and requiring pattern recognition or predictive capabilities. Here are some examples based on the context:
#
# 1. **Customer Service and Interaction**: AI can enhance customer service by handling routine inquiries and tasks, freeing up human employees to focus on more complex issues. For instance, the Swedish bank SEB uses an AI-driven virtual assistant named AIDA to respond to customer queries and even detect customer moods to tailor its responses.
#
# 2. **Predictive Maintenance**: Businesses can use AI to predict when equipment or machinery might fail, allowing for proactive maintenance and reducing downtime.
#
# 3. **Fraud Detection**: AI systems can analyze transaction patterns to identify potentially fraudulent activities in real-time, which is crucial for financial institutions.
#
# 4. **Targeted Advertising and Recommendation Engines**: AI can analyze consumer behavior to deliver personalized recommendations and targeted advertisements, enhancing marketing strategies.
#
# 5. **Healthcare Diagnostics**: AI is already outperforming humans in diagnosing certain conditions, such as skin cancer, by analyzing medical images more accurately and quickly.
#
# 6. **Operational Efficiency**: In sectors like manufacturing
#
# === ANSWER TO QUESTION 11 ===
#
# The context provided does not contain specific information on how teams should collaborate when building AI projects. It discusses various aspects of AI development, such as ethical considerations, data sovereignty, and the political economy of data, but it does not address team collaboration strategies directly. Therefore, I cannot provide a detailed answer based on the given context.

# %%
len(answers[0])
# Out:
# 1421

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:824/1*GK56xmDIWtNQAD_jnBIt2g.png" alt="NLP Gif" style="width: 500px">

# %% [markdown]
# <h2 style="color: #FF6347;">Cosine Similarity</h2>
#
# **Cosine similarity** is a metric used to measure the alignment or similarity between two vectors, calculated as the cosine of the angle between them. It is the **most common metric used in RAG pipelines** for vector retrieval.. It provides a scale from -1 to 1:
#
# - **-1**: Vectors are completely opposite.
# - **0**: Vectors are orthogonal (uncorrelated or unrelated).
# - **1**: Vectors are identical.

# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/cosine-similarity-vectors.original.jpg" alt="NLP Gif" style="width: 700px">

# %% [markdown]
# <h2 style="color: #FF6347;">Keyword Highlighting</h2>
#
# Highlighting important keywords helps users quickly understand the relevance of the retrieved text to their query.

# %%
from termcolor import colored

# %% [markdown]
# The `highlight_keywords` function is designed to highlight specific keywords within a given text. It replaces each keyword in the text with a highlighted version using the `colored` function from the `termcolor` library.

# %%
from termcolor import colored

def highlight_keywords(texts, keywords):
    highlighted_texts = []

    for text in texts:
        modified = text
        for keyword in keywords:
            modified = modified.replace(
                keyword,
                colored(keyword, "red", attrs=["bold"])
            )
        highlighted_texts.append(modified)

    return highlighted_texts

# %% [markdown]
# ### Exercice4: add your keywords

# %%
query_keywords = ["AI", "machine learning", "data", "business", "strategy", "automation", "decision-making", "use case", "deployment", "organization"]
for i, docs in enumerate(results) :
    for j, doc in enumerate(docs[:1]):
        text = doc.page_content # RETRIVE THE TEXT
        snippet = text[:1000] # EXTRACT A SNIPPET
        highlighted = highlight_keywords([snippet], query_keywords) # HIGHLIGHT_KEYWORDS EXPECTS A LIST OF STRINGS
        print(f"Snippet {j+1}:\n{highlighted[0]}\n{'-'*80}")
# Out:
# Snippet 1:
# or cybernetics).
# Artificial intelligence can be classified into three types of systems: analyti -
# cal, human-inspired and humanised (Kaplan and Haenlein 2019). Analytical
# AI contains characteristics consistent with cognitive intelligence only: gener -
# ating cognitive representation of the world and using learning based on past
# experience to inform future decisions. Human-inspired AI contains elements
# of cognitive and emotional intelligence: understanding human emotions,
# in addition to cognitive elements, and considering them in their decision-
# making. Humanised AI contains characteristics of all types of competencies
# (i.e., cognitive, emotional and social intelligence), is able to be self-conscious,
# and is self-aware in interactions with others.
# A robot driven by analytical artificial intelligence would be capable of
# answering queries concerning restaurant recommendations based on certain
# --------------------------------------------------------------------------------
# Snippet 1:
# used for other tasks within the job, and does not necessarily lead to a human
# being’s replacement. The Swedish bank, SEB, e.g., developed AIDA, an AI-
# driven virtual assistant responding to a vast range of customers’ queries, such
# as how to make overseas payments or how to proceed when opening a bank
# account. AIDA is even capable of detecting a customer’s mood by the tone of
# her or his voice and adapting its recommendations and suggestions thereto. In
# around 30% of situations, AIDA is not able to respond or help. In this case, the
# customer is transferred to a human. AIDA ’s implementation freed up human
# employees’ time, which they then use for more complex demands, i.e., the 30%
# that exceeded AIDA ’s limitations.
# A study by Wilson and Daugherty (2018, 117) suggested that it is in com -
# panies’ interest not to replace employees with AI, as this would not be a long-
# term strategy. Looking at 1,500 corporations, they identified the best improve-
# --------------------------------------------------------------------------------
# Snippet 1:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
# lack the ability to learn autonomously from external data, they should defi -
# nitely not be counted as AI. Expert systems reconstruct human intelligence in
# a top-down manner (also called the knowledge-based or symbolic approach),
# considering that it can be codified as a set of predefined rules. In contrast, AI
# applies a bottom-up approach (also called the behaviour-based or connection-
# ist approach) and imitates a brain’s set-up (e.g., through neural networks) by
# using large quantities of data to infer knowledge independently.
# The question that arises is what will remain human in the future and what
# cannot be imitated by AI systems, which is quite a tough question to answer.
# Most likely, humans will always have exclusivity when it comes to artistic crea-
# --------------------------------------------------------------------------------
# Snippet 1:
# 24 AI for Everyone?
# objective characteristics. Human-inspired AI robots could additionally read a
# human’s emotional state via facial recognition or tone of voice, and adapt its
# suggestions, e.g., a human who appears sad or depressed would not enjoy a res-
# taurant with a lively atmosphere, whereas a happy human might totally enjoy
# such an environment. Finally, a humanised robot would understand when it
# was appropriate for it to offer to accompany the human or whenever this would
# not be appreciated, e.g., a couple insanely in love who would rather spend the
# time in intimate togetherness.
# Finally, we must distinguish AI on the lower spectrum from so-called expert
# systems, often wrongly associated with artificial intelligence, as well as on
# the higher spectrum from skills that remain only possible for human beings:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
# --------------------------------------------------------------------------------
# Snippet 1:
# tion of AI capital. Finding bottlenecks returns us to the question of visibility,
# without which strategy cannot be formulated. I hope this chapter will contrib-
# ute to an incremental increase in visibility and, perhaps, a half step towards
# a strategy.
# References
# Accenture. n.d. AI for Business Transformation. https://www.accenture.com/us
# -en/services/applied-intelligence/business-transformation
# Agarwal, D. 2019. Chat with Kevin Scott EVP and CTO of Microsoft. 15 July.
# Venture Beat. Last accessed 5 May 2020: https://www.youtube.com/watch?v
# =npXxiVaY9p0
# Alharby, M. and Van Moorsel, A. 2017. Blockchain-Based Smart Contracts: A
# Systematic Mapping Study. arXiv preprint arXiv:1710.06372.
# Alpaydin, E. 2014. Introduction to Machine Learning . Cambridge, MA: MIT
# Press.
# Amadeo, R. 2018. Google’s Iron Grip on Android: Controlling Open Source by
# Any Means Necessary. 21 August. Ars Technica. Last accessed 5 May 2020:
# --------------------------------------------------------------------------------
# Snippet 1:
# PART 2
# Discourses and Myths
# About AI
# --------------------------------------------------------------------------------
# Snippet 1:
# at stake due to advances in AI.
# About Algorithms and Organisations
# When machines and humans coexist, it is important that both do what they are
# good at. As an illustration, let’s have a look at a study by researchers from MIT’s
# Computer Science and Artificial Intelligence Laboratory in cooperation with
# the machine-learning startup PatternEx (Conner-Simons 2016). AI systems
# and humans scored far better in identifying cyber-attacks when collaborating
# than when trying to do so separately. While the AI systems could crawl through
# enormous quantities of big data, humans were better at detecting anomalies,
# playing those back into the system. This iterative and collaborative approach
# was optimal.
# Also, humans are better in behaving ethically and morally, while algorithms
# have problems doing so, as the notion of ethics and morals is difficult to pro -
# gram. Machines, however, are better at, e.g., utilitarian, repetitive tasks. While
# --------------------------------------------------------------------------------
# Snippet 1:
# poses, there is concern about dangerous and problematic uses of the technol -
# ogy, which has prompted a global conversation on the normative principles
# to which AI ought adhere, under the banner of ‘ AI ethics’ . Governments, cor-
# porations and NGOs throughout the world have generated their own sets of
# AI ethics principles. Questions and critiques arise about the content of these
# ethics principles, whether they are actually implemented, and their (legal)
# enforceability (Wagner 2018). Broader issues emerge about the power and
# privilege of the organisations, governments and individuals which are creat -
# ing and implementing AI and accompanying ethical principles. For example,
# Google has recently announced an ethics service (Simonite 2020), yet has been
# mired in ethics controversies from violating privacy law (Finley 2019), work -
# ing on controversial military projects (Crofts and van Rijswijk 2020) and dis -
# --------------------------------------------------------------------------------
# Snippet 1:
# mathematical method for prediction (Agrawal et al. 2018). Such systems can be
# extremely powerful but are limited in the range of tasks they can perform.
# Russell and Norvig (2016) see machine learning as a prerequisite for intel -
# ligent machines. Machine learning is a paradigm that allows programs to auto-
# matically improve their performance on a particular task by learning from vast
# amounts of data (Alpaydin 2016). It seeks and uses statistical patterns and cor-
# relation in enormous datasets. Unlike older types of AI (e.g. expert systems,
# that are based on rules which are inputted by humans), machine learning algo-
# rithms learn not from humans but from data. The availability of significant
# amounts of real-world data (that we produce by using the internet, social media,
# sensors or other Internet-of-Things applications), combined with the availabil-
# ity of powerful and almost limitless computing capacity and advancements in
# --------------------------------------------------------------------------------
# Snippet 1:
# 24 AI for Everyone?
# objective characteristics. Human-inspired AI robots could additionally read a
# human’s emotional state via facial recognition or tone of voice, and adapt its
# suggestions, e.g., a human who appears sad or depressed would not enjoy a res-
# taurant with a lively atmosphere, whereas a happy human might totally enjoy
# such an environment. Finally, a humanised robot would understand when it
# was appropriate for it to offer to accompany the human or whenever this would
# not be appreciated, e.g., a couple insanely in love who would rather spend the
# time in intimate togetherness.
# Finally, we must distinguish AI on the lower spectrum from so-called expert
# systems, often wrongly associated with artificial intelligence, as well as on
# the higher spectrum from skills that remain only possible for human beings:
# Expert systems are ‘collections of rules programmed by humans in the form
# of if > then statements’ (Kaplan and Haenlein 2019, p. 18). As these systems
# --------------------------------------------------------------------------------
# Snippet 1:
# 30 AI for Everyone?
# Future research will be needed to address the various challenges with regards to
# the development of artificial intelligence. Which formal method can be used
# to test for algorithmic bias? Can we identify simple to use measures to assess
# bias, similar to the way we assess reliability and validity? What is the best way to
# bridge (deep) learning and privacy? Should learning be conducted on the user
# side (with algorithms requiring new data)? Or should data be transferred to a
# trusted intermediary who performs the analysis on behalf of firms? Do users
# need to be compensated in one way or another for data or resources provided?
# Moreover, how can the refusal to share data lead to biases in the data available
# for learning? Which data sources can and should be used for algorithmic learn-
# ing? Are there certain types of data that should be ‘off-limits’? What role will
# interdisciplinary AI teams play in establishing coexistence between humans
# --------------------------------------------------------------------------------

# %% [markdown]
# 1. `query_keywords` is a list of keywords to be highlighted.
# 2. The loop iterates over the first document in retrieved_docs.
# 3. For each document, a snippet of the first 200 characters is extracted.
# 4. The highlight_keywords function is called to highlight the keywords in the snippet.
# 5. The highlighted snippet is printed along with a separator line.

# %% [markdown]
# <h1 style="color: #FF6347;">Bonus</h1>

# %% [markdown]
# **Try loading one of your own PDF books and go through the steps again to explore how the pipeline works with your content**:

# %%
# LOAD AND SPLIT THE DOCUMENT
loader_bonus = PyPDFLoader("../../../../../../BUSINESS/MARICEL BUSINESS/ENTREPRENDRE_DANS_LE_CHAOS/Entreprendre dans le Chaos - Manuscrit V1.pdf")
pages_bonus = loader_bonus.load_and_split()
len(pages_bonus)
# Out:
# 445

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks_bonus = text_splitter.split_documents(pages_bonus)
len(chunks_bonus)
# Out:
# 874

# %%
db_bonus = Chroma.from_documents(chunks_bonus, embeddings, persist_directory="../../chroma_db_LAB_bonus")
print("ChromaDB created with document embeddings.")
# Out:
# ChromaDB created with document embeddings.

# %%
user_question_bonus = ["Comment un entrepreneur peut-il transformer une période de chaos en opportunité stratégique ?",
                       "Quelles sont les qualités essentielles pour entreprendre dans un environnement instable ou imprévisible ?",
                       "Comment identifier les signaux faibles qui annoncent un changement majeur dans un marché ?",
                       "Quels types de décisions doivent être prises rapidement en période de crise, et lesquelles doivent être différées ?",
                       "Comment une entreprise peut-elle rester résiliente face à des perturbations économiques ou sociales ?",
                       "Quels sont les principaux risques auxquels un entrepreneur est confronté dans un contexte chaotique, et comment les gérer ?",
                       "Comment maintenir la motivation et la cohésion d’une équipe lorsque l’environnement externe devient incertain ?",
                       "Quelles stratégies permettent de naviguer efficacement dans un marché en transformation rapide ?",
                       "Comment un entrepreneur peut-il repenser son modèle économique pour survivre ou prospérer dans le chaos ?",
                       "Quel rôle joue l’innovation dans la capacité d’une entreprise à s’adapter à des conditions extrêmes ?",
                       "Comment développer une vision claire et mobilisatrice lorsque le futur est difficile à anticiper ?"] # User question

results_bonus = []  # to store the results for each question

for question in user_question_bonus:
    retrieved_docs_bonus = db_bonus.similarity_search(question, k=30) # k is the number of documents to retrieve
    results_bonus.append(retrieved_docs_bonus)

# %%
print(results_bonus[0])
# Out:
# [Document(id='4e7c3770-d6b6-4e3a-a564-bca1d9d66b03', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'moddate': '2026-05-29T14:56:45+02:00', 'page': 412, 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'total_pages': 446, 'creationdate': '2026-05-29T14:56:45+02:00', 'source': '../../../../../../BUSINESS/MARICEL BUSINESS/ENTREPRENDRE_DANS_LE_CHAOS/Entreprendre dans le Chaos - Manuscrit V1.pdf', 'page_label': '413'}, page_content='ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS \n \n411 \n \nDans le chaos, les systèmes rigides, lourds de bureaucratie ou \nd’une inertie forte, échouent. L’environnement les brise. Les sys-\ntèmes adaptatifs, eux, prospèrent. Leur souplesse structurelle est \nleur première arme concurrentielle. \nL’entrepreneur stratège ne gaspille pas son énergie à éradiquer \nle chaos. Une telle ambition relève de l’illusion. Son effort porte \nsur sa compréhension profonde et son utilisation. \nIl dresse une cartographie précise : \n● Les zones d’inefficience structurelle : Ce sont les failles \ndu système (distribution lacunaire, services publics défi-\ncients, infrastructures obsolètes). Pour l’entrepreneur, \nelles se muent en demande de solutions privées de subs-\ntitution. \n● Les vides institutionnels ou légaux : Là où l’État est ab-\nsent ou la loi incertaine, une place existe pour celui qui \npropose un cadre clair ou un service de confiance. \n● Les besoins non couverts par le système formel : L’accès'), Document(id='ea563d9b-4e3f-45f9-a699-bb18fc35d460', metadata={'page_label': '358', 'creationdate': '2026-05-29T14:56:45+02:00', 'moddate': '2026-05-29T14:56:45+02:00', 'page': 357, 'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'total_pages': 446, 'source': '../../../../../../BUSINESS/MARICEL BUSINESS/ENTREPRENDRE_DANS_LE_CHAOS/Entreprendre dans le Chaos - Manuscrit V1.pdf'}, page_content="356 \n \nLe chaos, loin de représenter une force de destruction pure, \nconstitue un environnement naturel pour l'entrepreneur congo-\nlais. Ce contexte impose un changement de paradigme, passant \nde la simple survie à une croissance provoquée par la perturba-\ntion. \nUne entreprise peut se définir selon son interaction avec l’in-\ncertitude : \n1. L’entreprise fragile est une structure qui subit le chaos, \noù le moindre choc se révèle une source de dégât majeur. \nSa rigidité la destine à la rupture. \n2. L’entreprise robuste cherche l'endurance. Elle supporte \nle chaos, il glisse sur elle, mais ne crée aucune valeur. Elle \nmaintient son état initial, une posture statique face au \nmouvement du marché. \n3. L’entreprise anti-fragile excède la simple résilience. Elle \ntire profit des chocs, du stress, de la volatilité pour gran-\ndir, gagner en force et optimiser ses systèmes. Elle trouve \ndans le désordre une puissance motrice. \nComment un entrepreneur en RDC peut -il ériger une telle"), Document(id='f1c848de-8442-4d23-af90-1f3b20c74ef5', metadata={'moddate': '2026-05-29T14:56:45+02:00', 'creationdate': '2026-05-29T14:56:45+02:00', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'page_label': '103', 'source': '../../../../../../BUSINESS/MARICEL BUSINESS/ENTREPRENDRE_DANS_LE_CHAOS/Entreprendre dans le Chaos - Manuscrit V1.pdf', 'total_pages': 446, 'page': 102, 'producer': 'Microsoft® Word pour Microsoft\xa0365'}, page_content='ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS \n \n101 \n \nEt c’est cette lecture du réel qui distingue les entrepreneurs \nqui subissent le chaos… De ceux qui le transforment en avantage \nstructurel.'), Document(id='dd6bdf2a-6127-479b-8156-7f636d6a5e79', metadata={'moddate': '2026-05-29T14:56:45+02:00', 'page_label': '412', 'creationdate': '2026-05-29T14:56:45+02:00', 'page': 411, 'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'source': '../../../../../../BUSINESS/MARICEL BUSINESS/ENTREPRENDRE_DANS_LE_CHAOS/Entreprendre dans le Chaos - Manusc ...

# %%
# DISPLAY TOP RESULTS
for i, docs in enumerate(results_bonus) :
    print(f"\n=== QUESTION {i+1} ===")
    for j, item in enumerate(docs[:3]) :
        print(f"\nDOCUMENT {j+1} : \n{item.page_content[36:1000]}\n")
# Out:
# === QUESTION 1 ===
#
# DOCUMENT 1 :
# STIAN BOSMANS
#
# 411
#
# Dans le chaos, les systèmes rigides, lourds de bureaucratie ou
# d’une inertie forte, échouent. L’environnement les brise. Les sys-
# tèmes adaptatifs, eux, prospèrent. Leur souplesse structurelle est
# leur première arme concurrentielle.
# L’entrepreneur stratège ne gaspille pas son énergie à éradiquer
# le chaos. Une telle ambition relève de l’illusion. Son effort porte
# sur sa compréhension profonde et son utilisation.
# Il dresse une cartographie précise :
# ● Les zones d’inefficience structurelle : Ce sont les failles
# du système (distribution lacunaire, services publics défi-
# cients, infrastructures obsolètes). Pour l’entrepreneur,
# elles se muent en demande de solutions privées de subs-
# titution.
# ● Les vides institutionnels ou légaux : Là où l’État est ab-
# sent ou la loi incertaine, une place existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
#
#
# DOCUMENT 2 :
#  une force de destruction pure,
# constitue un environnement naturel pour l'entrepreneur congo-
# lais. Ce contexte impose un changement de paradigme, passant
# de la simple survie à une croissance provoquée par la perturba-
# tion.
# Une entreprise peut se définir selon son interaction avec l’in-
# certitude :
# 1. L’entreprise fragile est une structure qui subit le chaos,
# où le moindre choc se révèle une source de dégât majeur.
# Sa rigidité la destine à la rupture.
# 2. L’entreprise robuste cherche l'endurance. Elle supporte
# le chaos, il glisse sur elle, mais ne crée aucune valeur. Elle
# maintient son état initial, une posture statique face au
# mouvement du marché.
# 3. L’entreprise anti-fragile excède la simple résilience. Elle
# tire profit des chocs, du stress, de la volatilité pour gran-
# dir, gagner en force et optimiser ses systèmes. Elle trouve
# dans le désordre une puissance motrice.
# Comment un entrepreneur en RDC peut -il ériger une telle
#
#
# DOCUMENT 3 :
# STIAN BOSMANS
#
# 101
#
# Et c’est cette lecture du réel qui distingue les entrepreneurs
# qui subissent le chaos… De ceux qui le transforment en avantage
# structurel.
#
#
# === QUESTION 2 ===
#
# DOCUMENT 1 :
# STIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
#
#
# DOCUMENT 2 :
# tabilité
# n’est pas une anomalie
#
# Le postulat de base de l’entrepreneur qui réussit sur un terrain
# complexe exige un changement de paradigme : l’instabilité n’est
# pas une anomalie transitoire, elle constitue un élément structurel
# de l’environnement stratégique.
# L’une des erreurs les plus coûteuses, un écueil que de nom-
# breux investisseurs et entrepreneurs font leur, consiste à consi-
# dérer le désordre comme un accident passager.
# La voix du doute murmure :
# “Lorsque l’horizon s’éclaircira, que la situation se stabilisera,
# alors j’investirai avec force. “
# Attendre un environnement parfait, poli par une administra-
# tion idéale ou une politique sans heurts, s’avère une stratégie de
# paralysie. L’histoire économique mondiale donne le contrepoint.
# Les plus grandes fortunes émergent précisément des périodes de
# déséquilibre profond. Ces moments ne sont pas des freins ; ils
# sont des catalyseurs.
#
#
# DOCUMENT 3 :
# STIAN BOSMANS
#
# 359
#
# un investissement majeur, ou favoriser un concurrent.
# Ce manque de prévisibilité est un frein majeur à l’essor
# d’une économie formelle robuste. L’incertitude régle-
# mentaire détruit la confiance, fondement de tout déve-
# loppement économique durable.
# Ce sujet possède une nature délicate. Nier son existence, ou
# prétendre le système fonctionne sans accroc, serait un signe
# d’hypocrisie coupable. La seule position tenable est celle d’un
# pragmatisme lucide et guerrier. L'entrepreneur visionnaire re-
# connaît l'existence de cette réalité sans pour autant s'y soumettre
# avec passivité.
# La véritable question pour le bâtisseur économique ne réside
# pas dans l’utopie d’un environnement sans défaut. Elle réside
# dans l’art supérieur de la navigation :
# Comment maintenir un cap stratégique sans détruire son in-
# tégrité éthique, sans fragiliser l’entreprise face au chantage, et
# sans mettre en danger l’équipe opérationnelle ?
#
#
# === QUESTION 3 ===
#
# DOCUMENT 1 :
#  existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
# à la finance, à l’énergie, à l’éducation de qualité pour la
# majorité de la population. Ce déficit incarne un marché
# colossal.
# ● Les flux informels de l’économie : Il apprend à décoder
# les circuits de l’ombre, la logique des marchés populaires,
# source d’une trésorerie réelle.
# ● Les ruptures structurelles (politique, technologique, géo-
# politique) : Chaque choc crée une réorganisation du pou-
# voir et des marchés, offrant un avantage aux premiers
# positionnés.
# Fort de cette analyse, l’entrepreneur construit son œuvre à
# partir de ces éléments, non contre eux.
# Ce renversement de perspective est une action fondatrice : Le
# chaos ne constitue pas un obstacle rédhibitoire à la création de
#
#
# DOCUMENT 2 :
# récisément des périodes de
# déséquilibre profond. Ces moments ne sont pas des freins ; ils
# sont des catalyseurs.
#
# Pourquoi ce phénomène ? Car les périodes de crise, qu’elles
# soient financières, politiques ou sécuritaires, opèrent une puis-
# sante sélection darwinienne. Elles démantèlent les modèles an-
# ciens, détruisent les rentes obsolètes et ouvrent un espace vierge
# à l’innovation radicale. Les acteurs qui tardent, qui craignent le
# risque, restent prisonniers des structures antérieures. Ceux qui
# agissent saisissent des actifs sous -valorisés, occupent des mar-
# chés désertés et bâtissent leur suprématie sur les ruines du passé.
#
#
# DOCUMENT 3 :
# tabilité
# n’est pas une anomalie
#
# Le postulat de base de l’entrepreneur qui réussit sur un terrain
# complexe exige un changement de paradigme : l’instabilité n’est
# pas une anomalie transitoire, elle constitue un élément structurel
# de l’environnement stratégique.
# L’une des erreurs les plus coûteuses, un écueil que de nom-
# breux investisseurs et entrepreneurs font leur, consiste à consi-
# dérer le désordre comme un accident passager.
# La voix du doute murmure :
# “Lorsque l’horizon s’éclaircira, que la situation se stabilisera,
# alors j’investirai avec force. “
# Attendre un environnement parfait, poli par une administra-
# tion idéale ou une politique sans heurts, s’avère une stratégie de
# paralysie. L’histoire économique mondiale donne le contrepoint.
# Les plus grandes fortunes émergent précisément des périodes de
# déséquilibre profond. Ces moments ne sont pas des freins ; ils
# sont des catalyseurs.
#
#
# === QUESTION 4 ===
#
# DOCUMENT 1 :
# olitique de réduc-
# tion des coûts drastique et rapide.
# Chacun de ces scénarios doit avoir une réponse opération-
# nelle rédigée, connue, et prête à être exécutée.
# Cette préparation réduit l’impact de la panique. Lorsque la
# crise advient, l'équipe ne cherche pas une solution sous le coup
# de l'urgence. Elle exécute un plan déjà validé, gage de survie et
# de maintien de la trajectoire stratégique. Le stratège congolais
# sait : la prévision donne une puissance d’action supérieure.
#
#
# DOCUMENT 2 :
# STIAN BOSMANS
#
# 395
#
# une véritable mentalité de survie. Lorsque la structure écono-
# mique d'une société vacille ou offre peu de visibilité, l'horizon
# temporel de l'individu se réduit drastiquement à l'immédiat.
# Cette logique de l'urgence s'exprime dans des objectifs
# simples, vitaux pour la continuité du quotidien, mais qui consti-
# tuent une impasse stratégique sur le long terme :
# ● Subsister : Assurer sa sécurité matérielle sur la journée.
# ● Résoudre l'immédiat : Éteindre les feux urgents, sans en-
# visager la prévention structurelle.
# ● Nourrir aujourd'hui : Concentrer ses efforts sur la sub-
# sistance alimentaire présente.
# ● Gagner l'instant : Privilégier le gain monétaire à court
# terme, au détriment de l'accumulation de capital ou de la
# construction d'actifs durables.
# Cette réaction est profondément humaine et révèle une adap-
# tation au milieu hostile. Elle devient pourtant une prison con-
#
#
# DOCUMENT 3 :
#  gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# de prospérer là où les autres s’effondrent.
# Un leadership éclairé sélectionne son personnel en fonction
# de ce prisme d’évaluation. Ces qualités forgent une équipe non
# pas réactive, mais véritablement anti-fragile.
#
#
# Embaucher lentement, remplacer
# rapidement
#
#
# === QUESTION 5 ===
#
# DOCUMENT 1 :
#  stratégique quand les
# concurrents subissent un repli brutal.
# Dans un environnement où l’instabilité structurelle est la
# norme, la possession d’une réserve financière saine ne relève pas
# du confort. Elle représente une exigence vitale, un levier de sou-
# veraineté pour l’entreprise face aux pressions externes. Le capital
# disponible confère la liberté d’action et la force de négociation.
#
#
# Construire une entreprise anti -
# fragile : le principe de la résilience
# dynamique
#
#
# DOCUMENT 2 :
#  gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# de prospérer là où les autres s’effondrent.
# Un leadership éclairé sélectionne son personnel en fonction
# de ce prisme d’évaluation. Ces qualités forgent une équipe non
# pas réactive, mais véritablement anti-fragile.
#
#
# Embaucher lentement, remplacer
# rapidement
#
#
# DOCUMENT 3 :
# STIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
#
#
# === QUESTION 6 ===
#
# DOCUMENT 1 :
# STIAN BOSMANS
#
# 343
#
# d’une forteresse interne, vulnérables à la moindre bourrasque du
# chaos environnant. L’entrepreneur stratège est celui qui fait de la
# survie un avantage concurrentiel majeur.
#
#
# Le risque n’est pas l’ennemi
#
# Beaucoup associent l’entreprise, l’action d’entreprendre, au
# courage. Ce lien est vrai. L'audace initie l’élan, mais elle doit se
# distinguer d’une imprudence stérile. Le véritable entrepreneur
# n’est point celui qui accepte tous les risques, par pure téméri té.
# C’est la figure qui comprend la nature profonde du risque, qui
# évalue avec lucidité ceux qu’il choisit de prendre, et ceux qu’il
# doit absolument neutraliser.
# En République Démocratique du Congo, le risque ne consti-
# tue pas un bloc monolithique à rejeter, il représente un prisme
# complexe. Il devient alors impératif d’analyser plusieurs catégo-
# ries de risques, car une stratégie d’entreprise solide repose sur
#
#
# DOCUMENT 2 :
# STIAN BOSMANS
#
# 359
#
# un investissement majeur, ou favoriser un concurrent.
# Ce manque de prévisibilité est un frein majeur à l’essor
# d’une économie formelle robuste. L’incertitude régle-
# mentaire détruit la confiance, fondement de tout déve-
# loppement économique durable.
# Ce sujet possède une nature délicate. Nier son existence, ou
# prétendre le système fonctionne sans accroc, serait un signe
# d’hypocrisie coupable. La seule position tenable est celle d’un
# pragmatisme lucide et guerrier. L'entrepreneur visionnaire re-
# connaît l'existence de cette réalité sans pour autant s'y soumettre
# avec passivité.
# La véritable question pour le bâtisseur économique ne réside
# pas dans l’utopie d’un environnement sans défaut. Elle réside
# dans l’art supérieur de la navigation :
# Comment maintenir un cap stratégique sans détruire son in-
# tégrité éthique, sans fragiliser l’entreprise face au chantage, et
# sans mettre en danger l’équipe opérationnelle ?
#
#
# DOCUMENT 3 :
# STIAN BOSMANS
#
# 411
#
# Dans le chaos, les systèmes rigides, lourds de bureaucratie ou
# d’une inertie forte, échouent. L’environnement les brise. Les sys-
# tèmes adaptatifs, eux, prospèrent. Leur souplesse structurelle est
# leur première arme concurrentielle.
# L’entrepreneur stratège ne gaspille pas son énergie à éradiquer
# le chaos. Une telle ambition relève de l’illusion. Son effort porte
# sur sa compréhension profonde et son utilisation.
# Il dresse une cartographie précise :
# ● Les zones d’inefficience structurelle : Ce sont les failles
# du système (distribution lacunaire, services publics défi-
# cients, infrastructures obsolètes). Pour l’entrepreneur,
# elles se muent en demande de solutions privées de subs-
# titution.
# ● Les vides institutionnels ou légaux : Là où l’État est ab-
# sent ou la loi incertaine, une place existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
#
#
# === QUESTION 7 ===
#
# DOCUMENT 1 :
#  gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# de prospérer là où les autres s’effondrent.
# Un leadership éclairé sélectionne son personnel en fonction
# de ce prisme d’évaluation. Ces qualités forgent une équipe non
# pas réactive, mais véritablement anti-fragile.
#
#
# Embaucher lentement, remplacer
# rapidement
#
#
# DOCUMENT 2 :
# STIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
#
#
# DOCUMENT 3 :
# roductibilité des succès
# et limite l’impact du chaos extérieur sur les opérations
# internes.
# ● La fiabilité absolue : L’instabilité de l’environnement
# augmente l’importance de la parole donnée. Une fiabilité
# sans faille des équipes constitue un actif rare, générant
# une confiance qui se monnaie en partenariats solides et
# en crédibilité bancaire, y compris face aux institutions in-
# ternationales.
# ● L’aptitude à l’apprentissage continu : Les règles du jeu
# changent vite. La capacité d’une équipe à assimiler de
# nouvelles compétences, à désapprendre des méthodes
#
#
# === QUESTION 8 ===
#
# DOCUMENT 1 :
# gidité est un risque mortel. L'opéra-
# teur qui s’entête à poursuivre une voie non viable finit par épui-
# ser son capital, son temps, et sa crédibilité.
# La survie exige une souplesse stratégique, une aptitude réelle
# à la réinvention. Il faut accepter que le succès passe par une mu-
# tation profonde de l'entreprise :
# ● Changer de produit ou de service : Les besoins réels des
# populations ou des entreprises peuvent différer de l’offre
# pensée au départ. Le pivot stratégique, souvent incon-
# fortable, est une nécessité vitale.
# ● Changer de modèle économique : Un système de tarifi-
# cation ou de distribution inadapté au contexte congolais
# (logistique lourde, faible pouvoir d'achat) voue le projet
# à l'échec. L'exploration de nouveaux circuits de revenus
# est capitale.
# ● Changer de clientèle (segmentation) : Le marché peut re-
# jeter la cible envisagée ou, à l'inverse, révéler un segment
# plus porteur mais ignoré au départ (l’accès à la diaspora,
#
#
# DOCUMENT 2 :
# e (segmentation) : Le marché peut re-
# jeter la cible envisagée ou, à l'inverse, révéler un segment
# plus porteur mais ignoré au départ (l’accès à la diaspora,
# par exemple).
# ● Changer de stratégie opérationnelle : La méthode de
# mise en œuvre ne tient pas face aux défis logistiques ou
# réglementaires locaux. Une refonte du plan d’action
# s’impose.
# L'adaptation n'est en rien un abandon de la vision fondatrice
# ou de la flamme entrepreneuriale. Au contraire, elle représente la
# preuve d'un engagement supérieur : protéger la mission essen-
# tielle de l'entreprise. La mission est pérenne (par exemple : amé-
# liorer l'accès à l'énergie), tandis que la stratégie pour l'atteindre
# doit rester fluide face aux vents contraires du chaos. L'entrepre-
# neur avisé met sa vision au service de sa mission, et non l'inverse.
#
#
# DOCUMENT 3 :
# rship stratégique : transfor-
# mer une  confrontation frontale en une architecture de valeur
# complexe.
#
#
# L’adaptation permanente
#
# Dans le contexte singulier du Congo, une qualité surpasse
# toutes les autres pour bâtir une entreprise pérenne : l’adaptation.
# Elle se révèle plus puissante que la force brute, plus utile que
# l’intelligence académique, et bien plus décisive que l’importance
# du capital.
# Le monde change à vive allure. Les marchés mondiaux con-
# naissent des fluctuations fortes. Les technologies transforment
#
#
# === QUESTION 9 ===
#
# DOCUMENT 1 :
#  une force de destruction pure,
# constitue un environnement naturel pour l'entrepreneur congo-
# lais. Ce contexte impose un changement de paradigme, passant
# de la simple survie à une croissance provoquée par la perturba-
# tion.
# Une entreprise peut se définir selon son interaction avec l’in-
# certitude :
# 1. L’entreprise fragile est une structure qui subit le chaos,
# où le moindre choc se révèle une source de dégât majeur.
# Sa rigidité la destine à la rupture.
# 2. L’entreprise robuste cherche l'endurance. Elle supporte
# le chaos, il glisse sur elle, mais ne crée aucune valeur. Elle
# maintient son état initial, une posture statique face au
# mouvement du marché.
# 3. L’entreprise anti-fragile excède la simple résilience. Elle
# tire profit des chocs, du stress, de la volatilité pour gran-
# dir, gagner en force et optimiser ses systèmes. Elle trouve
# dans le désordre une puissance motrice.
# Comment un entrepreneur en RDC peut -il ériger une telle
#
#
# DOCUMENT 2 :
# STIAN BOSMANS
#
# 411
#
# Dans le chaos, les systèmes rigides, lourds de bureaucratie ou
# d’une inertie forte, échouent. L’environnement les brise. Les sys-
# tèmes adaptatifs, eux, prospèrent. Leur souplesse structurelle est
# leur première arme concurrentielle.
# L’entrepreneur stratège ne gaspille pas son énergie à éradiquer
# le chaos. Une telle ambition relève de l’illusion. Son effort porte
# sur sa compréhension profonde et son utilisation.
# Il dresse une cartographie précise :
# ● Les zones d’inefficience structurelle : Ce sont les failles
# du système (distribution lacunaire, services publics défi-
# cients, infrastructures obsolètes). Pour l’entrepreneur,
# elles se muent en demande de solutions privées de subs-
# titution.
# ● Les vides institutionnels ou légaux : Là où l’État est ab-
# sent ou la loi incertaine, une place existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
#
#
# DOCUMENT 3 :
# STIAN BOSMANS
#
# 371
#
# les modèles à un rythme élevé. Les crises, qu’elles soient sani-
# taires, politiques ou sécuritaires, surgissent sans avertissement.
# Face à ce mouvement perpétuel, l'entrepreneur congolais doit
# posséder un temps d'avance, il doit changer plus vite que son
# environnement.
# Cette adaptation constante n'est pas une simple survie passive
# ; elle est une stratégie offensive. Elle exige une veille active des
# signaux faibles, une capacité à pivoter les modèles d’affaires sans
# délai, et une intelligence situationnelle de chaque instant. L'atta-
# chement à un plan rigide ou à une méthode unique est une vul-
# nérabilité fatale sous ces latitudes. Seule la souplesse donne la
# suprématie. L'entrepreneur qui refuse cette fluidité se condamne
# à l'obsolescence, sa structure devient alors une cible  pour le
# chaos.
#
#
# Le danger de l’attachement excessif
#
# L'attachement à l'idée initiale constitue un piège psycholo-
#
#
# === QUESTION 10 ===
#
# DOCUMENT 1 :
# STIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
#
#
# DOCUMENT 2 :
#  stratégique quand les
# concurrents subissent un repli brutal.
# Dans un environnement où l’instabilité structurelle est la
# norme, la possession d’une réserve financière saine ne relève pas
# du confort. Elle représente une exigence vitale, un levier de sou-
# veraineté pour l’entreprise face aux pressions externes. Le capital
# disponible confère la liberté d’action et la force de négociation.
#
#
# Construire une entreprise anti -
# fragile : le principe de la résilience
# dynamique
#
#
# DOCUMENT 3 :
# rship stratégique : transfor-
# mer une  confrontation frontale en une architecture de valeur
# complexe.
#
#
# L’adaptation permanente
#
# Dans le contexte singulier du Congo, une qualité surpasse
# toutes les autres pour bâtir une entreprise pérenne : l’adaptation.
# Elle se révèle plus puissante que la force brute, plus utile que
# l’intelligence académique, et bien plus décisive que l’importance
# du capital.
# Le monde change à vive allure. Les marchés mondiaux con-
# naissent des fluctuations fortes. Les technologies transforment
#
#
# === QUESTION 11 ===
#
# DOCUMENT 1 :
# nir automatique :
# “ Qu’est-ce qui pourrait interrompre mon activité demain ? “
# Puis :
# “ Que puis-je faire aujourd’hui pour réduire cette menace ? “
#
#
# La règle des scénarios
#
# L'approche opérationnelle de nombre d’entreprises congo-
# laises repose sur un unique postulat : le scénario idéal. Cette pro-
# jection, dangereuse, ignore la nature volatile de l'environnement
# d'affaires à Kinshasa, Lubumbashi ou Goma.
# Un stratège d'entreprise, à l'inverse, prépare l’action à partir
# de plusieurs réalités possibles, cartographiant le chaos pour
# mieux le dominer. Adopter la règle des scénarios impose une
# discipline de guerre, celle qui envisage le pire pour pouvoir y faire
# face avec force.
# Cette méthode se structure autour de l'identification des me-
# naces majeures :
# ● Scénario A : La Croissance Normale (Le Rêve)
# Toutes les variables économiques, logistiques et poli-
# tiques évoluent favorablement. Il s’agit du plan de con-
# quête optimal.
#
#
# DOCUMENT 2 :
# STIAN BOSMANS
#
# 359
#
# un investissement majeur, ou favoriser un concurrent.
# Ce manque de prévisibilité est un frein majeur à l’essor
# d’une économie formelle robuste. L’incertitude régle-
# mentaire détruit la confiance, fondement de tout déve-
# loppement économique durable.
# Ce sujet possède une nature délicate. Nier son existence, ou
# prétendre le système fonctionne sans accroc, serait un signe
# d’hypocrisie coupable. La seule position tenable est celle d’un
# pragmatisme lucide et guerrier. L'entrepreneur visionnaire re-
# connaît l'existence de cette réalité sans pour autant s'y soumettre
# avec passivité.
# La véritable question pour le bâtisseur économique ne réside
# pas dans l’utopie d’un environnement sans défaut. Elle réside
# dans l’art supérieur de la navigation :
# Comment maintenir un cap stratégique sans détruire son in-
# tégrité éthique, sans fragiliser l’entreprise face au chantage, et
# sans mettre en danger l’équipe opérationnelle ?
#
#
# DOCUMENT 3 :
# olitique de réduc-
# tion des coûts drastique et rapide.
# Chacun de ces scénarios doit avoir une réponse opération-
# nelle rédigée, connue, et prête à être exécutée.
# Cette préparation réduit l’impact de la panique. Lorsque la
# crise advient, l'équipe ne cherche pas une solution sous le coup
# de l'urgence. Elle exécute un plan déjà validé, gage de survie et
# de maintien de la trajectoire stratégique. Le stratège congolais
# sait : la prévision donne une puissance d’action supérieure.

# %%
# GENERATE A FORMATTED CONTEXT FROM THE RETRIEVED DOCUMENTS
formatted_contexts_bonus = []

for docs in results_bonus:
    formatted_contexts_bonus.append(_get_document_prompt(docs))

print("CONTEXTS FORMATTED FOR GPT MODEL.")
# Out:
# CONTEXTS FORMATTED FOR GPT MODEL.

# %%
prompts_bonus = []

for question, context in zip(user_question_bonus, formatted_contexts_bonus):

    prompt_bonus = f"""
    Tu es un assistant aidant un entrepreneur ou un dirigeant à comprendre comment 
    agir, décider et s’adapter dans des périodes de chaos, d’incertitude ou de transformation.
    En t’appuyant uniquement sur les informations du contexte fourni, explique la réponse 
    de manière claire, pratique et orientée terrain. Mets l’accent sur la résilience, 
    la prise de décision, la stratégie adaptative, le leadership et les opportunités 
    qui émergent dans l’instabilité. Si le contexte ne contient pas assez d’informations, 
    dis-le explicitement.
    
    Question de l’utilisateur :
    {question}
    
    Contexte :
    {context}
    
    Réponse :
    """
    prompts_bonus.append(prompt_bonus)

# %%
model_params_bonus = {
    "model" : "gpt-4o",
    "temperature" : 0.2,       # LOW CREATIVITY => MORE FACTUAL AND GROUNDED
    "max_tokens" : 1000,        # ALLOW FOR DETAILED ANSWERS
    "top_p" : 0.9,             # BALANCED NUCLEUS SAMPLING
    "frequency_penalty" : 0.2, # REDUCE REPETITION
    "presence_penalty" : 0.1   # SLIGHTLY ENCOURAGE NEW IDEAS
}

# %%
answers_bonus = []

for prompt in prompts_bonus :
    messages = [{"role" : "user", "content" : prompt}]
    completion = client.chat.completions.create(
        messages=messages,
        **model_params_bonus,
        timeout=120
    )
    answers_bonus.append(completion.choices[0].message.content)

# %%
for index, answer in enumerate(answers_bonus) :
    print(f"\n=== ANSWER TO QUESTION {index+1} ===\n{user_question_bonus[index]}\n")
    print(answer, "\n\n")
# Out:
# === ANSWER TO QUESTION 1 ===
# Comment un entrepreneur peut-il transformer une période de chaos en opportunité stratégique ?
#
# Pour transformer une période de chaos en opportunité stratégique, un entrepreneur doit adopter une approche proactive et adaptative, en tirant parti des caractéristiques uniques de l'environnement chaotique. Voici quelques stratégies pratiques basées sur le contexte fourni :
#
# 1. **Adopter une mentalité anti-fragile** : Plutôt que de simplement résister au chaos, un entrepreneur doit chercher à en tirer parti. Les entreprises anti-fragiles prospèrent dans l'incertitude en utilisant les chocs et le stress pour se renforcer. Cela implique de voir le chaos non pas comme un obstacle, mais comme une opportunité de croissance et d'innovation.
#
# 2. **Cartographier les inefficiences et les vides** : Identifier les zones d'inefficience structurelle, les vides institutionnels ou légaux, et les besoins non couverts par le système formel peut révéler des opportunités pour offrir des solutions innovantes. Par exemple, là où les infrastructures sont obsolètes ou où l'État est absent, il y a une demande pour des services privés de substitution.
#
# 3. **Développer une stratégie adaptative** : La souplesse d'adaptation est cruciale. Un entrepreneur doit être prêt à pivoter rapidement et à reconfigurer son organisation face aux crises politiques, économiques ou logistiques. Cela nécessite une veille active des signaux faibles et une capacité à ajuster les modèles d'affaires sans délai.
#
# 4. **Construire une résilience structurelle** : Une entreprise doit être conçue pour prospérer dans le désordre. Cela implique de bâtir une organisation capable d'encaisser les chocs et de rebondir, en intégrant la volatilité comme un paramètre de conception.
#
# 5. **Exploiter le potentiel géopolitique** : Un entrepreneur peut jouer un rôle clé dans la transformation économique et sociale en structurant des industries et en influençant la politique économique. Cela va au-delà de la simple création d'entreprise pour devenir un acteur majeur du développement national.
#
# 6. **Évaluer et gérer les risques intelligemment** : Comprendre la nature complexe du risque dans un environnement chaotique est essentiel. L'entrepreneur doit évaluer avec lucidité quels risques prendre et lesquels neutraliser, transformant ainsi le risque en avantage concurrentiel.
#
# 7. **Foster innovation and creativity**: Chaos often dismantles old models and opens up space for radical innovation. Entrepreneurs should seize under-valued assets and deserted markets to build new value propositions and gain competitive advantage.
#
# En résumé, transformer le chaos en opportunité stratégique nécessite une compréhension profonde de l'environnement chaotique, une capacité à s'adapter rapidement, et une volonté d'innover continuellement. C'est cette approche qui permet à un entrepreneur non seulement de survivre, mais aussi de prospérer dans l'incertitude.
#
#
#
# === ANSWER TO QUESTION 2 ===
# Quelles sont les qualités essentielles pour entreprendre dans un environnement instable ou imprévisible ?
#
# Pour entreprendre dans un environnement instable ou imprévisible, certaines qualités essentielles se démarquent, comme le souligne le contexte fourni. Voici un résumé des qualités clés nécessaires :
#
# 1. **Adaptabilité et Souplesse** : La capacité à pivoter rapidement et à reconfigurer l'organisation face à des crises politiques, économiques ou logistiques est cruciale. Cela permet d'éviter la paralysie et de s'ajuster aux nouvelles réalités du marché.
#
# 2. **Résilience Psychologique** : Un environnement instable exige une solidité psychologique supérieure. La résilience collective et la gestion froide des situations critiques permettent à l'entreprise de non seulement survivre mais aussi de prospérer.
#
# 3. **Vision Stratégique et Discipline** : Comprendre que l'instabilité n'est pas une anomalie mais une constante structurelle est essentiel. Cela nécessite une discipline stratégique pour maintenir le cap malgré le chaos extérieur.
#
# 4. **Loyauté et Cohésion d'Équipe** : Dans un climat où les changements d'alliances sont fréquents, la loyauté du personnel clé assure la protection des informations stratégiques et la cohésion de l'entreprise.
#
# 5. **Capacité à Décoder le Chaos** : L'entrepreneur doit être capable de lire les signaux faibles, comprendre les dynamiques de pouvoir invisibles et transformer les faiblesses systémiques en opportunités stratégiques.
#
# 6. **Gestion du Risque** : Plutôt que d'éviter tous les risques, il est crucial de comprendre leur nature profonde, d'évaluer ceux qui peuvent être pris et ceux qui doivent être neutralisés.
#
# 7. **Création de Valeur dans le Désordre** : Les périodes de déséquilibre profond peuvent être des catalyseurs pour créer de la valeur. L'entrepreneur doit voir le chaos comme une opportunité plutôt qu'un obstacle.
#
# 8. **Leadership Inspirant** : Maintenir une posture de leadership inébranlable est essentiel pour guider l'équipe à travers les turbulences et inspirer confiance malgré l'incertitude.
#
# Ces qualités permettent non seulement de naviguer dans l'incertitude mais aussi d'en tirer parti pour construire une entreprise robuste et prospère dans un environnement chaotique.
#
#
#
# === ANSWER TO QUESTION 3 ===
# Comment identifier les signaux faibles qui annoncent un changement majeur dans un marché ?
#
# Pour identifier les signaux faibles annonçant un changement majeur dans un marché, il est essentiel de développer une approche proactive et stratégique, en s'appuyant sur les éléments suivants :
#
# 1. **Observation des Ruptures Structurelles** : Les changements politiques, technologiques ou géopolitiques peuvent être des indicateurs précoces de transformations majeures. Chaque choc crée une réorganisation du pouvoir et des marchés, offrant un avantage aux premiers positionnés. Il est crucial de surveiller ces ruptures pour anticiper les opportunités qui en découlent.
#
# 2. **Décodage des Flux Informels** : L'économie informelle, souvent le cœur réel des flux économiques, influence les prix, la distribution et la consommation. Analyser ces circuits permet de comprendre les véritables comportements des consommateurs et d'identifier des opportunités de structuration progressive.
#
# 3. **Veille Active et Intelligence Situationnelle** : Une veille active des signaux faibles est indispensable. Cela inclut l'analyse des modifications politiques, des variations douanières ou monétaires, et des repositionnements économiques régionaux. Ces éléments peuvent avoir un impact concret sur la rentabilité et la continuité d'une activité.
#
# 4. **Souplesse Stratégique et Capacité d'Adaptation** : L'attachement à un plan rigide est une vulnérabilité fatale. Il faut être prêt à pivoter rapidement, à reconfigurer l'organisation face à une crise ou à un changement soudain. Cette souplesse permet de transformer le chaos en levier stratégique.
#
# 5. **Lecture Stratégique du Terrain** : Comprendre les dynamiques locales, les centres d'influence, et les mécanismes informels offre un avantage stratégique considérable. Cela permet de distinguer les règles écrites des règles appliquées et d'identifier les véritables circuits de décision.
#
# 6. **Exploration des Vides Institutionnels ou Légaux** : Là où l'État est absent ou la loi incertaine, il existe une place pour proposer un cadre clair ou un service de confiance. Ces vides peuvent se transformer en demande de solutions privées de substitution.
#
# En somme, pour identifier les signaux faibles annonçant un changement majeur dans un marché, il est crucial d'adopter une approche flexible et proactive, en intégrant une veille stratégique continue et une capacité d'adaptation rapide aux nouvelles réalités du marché.
#
#
#
# === ANSWER TO QUESTION 4 ===
# Quels types de décisions doivent être prises rapidement en période de crise, et lesquelles doivent être différées ?
#
# En période de crise, la prise de décision doit être à la fois rapide et stratégique pour assurer la résilience et la survie de l'entreprise. Voici comment différencier les décisions qui nécessitent une action immédiate de celles qui peuvent être différées :
#
# ### Décisions à prendre rapidement :
#
# 1. **Gestion de la Trésorerie :** Assurer un cash-flow positif est crucial. Cela implique des décisions rapides sur la réduction des coûts non essentiels et l'optimisation des ressources financières pour maintenir l'oxygène vital de l'entreprise.
#
# 2. **Sécurité des Actifs et du Personnel :** Protéger les installations physiques et garantir l'intégrité du personnel sont des priorités immédiates. Cela peut nécessiter des mesures de sécurité renforcées ou des ajustements logistiques rapides.
#
# 3. **Réponse aux Scénarios Préparés :** Exécuter les plans d'urgence déjà établis pour différents scénarios (comme une rupture logistique ou une contraction du marché) permet d'agir sans panique et de minimiser les perturbations.
#
# 4. **Remplacement Rapide du Personnel Inefficace :** Dans un contexte instable, remplacer rapidement un collaborateur inapproprié est crucial pour maintenir la performance et le moral de l'équipe.
#
# 5. **Communication Transparente :** Informer rapidement toutes les parties prenantes (employés, clients, partenaires) sur les mesures prises renforce la confiance et la cohésion.
#
# ### Décisions à différer :
#
# 1. **Expansions Stratégiques :** Les projets d'expansion ou d'investissement majeur peuvent être différés jusqu'à ce que la situation se stabilise, permettant une évaluation plus précise des risques et opportunités.
#
# 2. **Recrutement Non Essentiel :** Embaucher dans l'urgence peut conduire à des erreurs coûteuses. Il est préférable de différer le recrutement jusqu'à ce que le besoin soit clairement défini et que le candidat idéal soit identifié.
#
# 3. **Changements Structurels Profonds :** Les transformations organisationnelles majeures nécessitent une réflexion approfondie et peuvent être différées pour éviter des perturbations supplémentaires en période de crise.
#
# 4. **Investissements en R&D à Long Terme :** Bien que l'innovation soit importante, certains investissements en recherche et développement peuvent être temporisés pour préserver les ressources financières immédiates.
#
# ### Stratégie Adaptative :
#
# - **Préparation et Scénarisation :** Avoir plusieurs scénarios prêts à être exécutés permet une adaptation rapide aux changements imprévus.
# - **Souplesse Organisationnelle :** Être capable de pivoter rapidement face aux nouvelles réalités du marché est essentiel pour éviter la paralysie.
# - **Veille Active :** Surveiller constamment les signaux faibles du marché pour anticiper les changements nécessaires.
#
# En résumé, en période de crise, il est crucial d'agir rapidement sur les aspects opérationnels critiques tout en différant les décisions stratégiques qui nécessitent une stabilité accrue pour être efficaces. La résilience repose sur une préparation minutieuse, une exécution disciplinée et une capacité à s'adapter avec agilité aux nouvelles conditions.
#
#
#
# === ANSWER TO QUESTION 5 ===
# Comment une entreprise peut-elle rester résiliente face à des perturbations économiques ou sociales ?
#
# Pour qu'une entreprise reste résiliente face à des perturbations économiques ou sociales, plusieurs stratégies clés peuvent être mises en œuvre, basées sur le contexte fourni :
#
# 1. **Diversification Stratégique** : Éviter la dépendance à un client unique, un fournisseur unique, ou une source de revenus unique est crucial. La diversification des secteurs d'activité, des marchés, et des sources de revenus permet de répartir le risque économique et d'absorber les chocs externes sans effondrement systémique.
#
# 2. **Réserve Financière** : Maintenir une réserve financière saine est vital. Cela offre à l'entreprise la liberté d'action et la force de négociation nécessaires pour naviguer dans des périodes de chaos. Une gestion stricte du flux de trésorerie et la constitution d'un fonds de réserve peuvent servir d'amortisseur contre les chocs imprévus.
#
# 3. **Leadership Éclairé et Résilience Collective** : Un leadership éclairé qui sélectionne son personnel sur la base de leur résilience et capacité à gérer les situations critiques est essentiel. La résilience collective et l'absence de panique permettent à l'entreprise non seulement de survivre mais aussi de prospérer là où d'autres échouent.
#
# 4. **Adaptabilité et Souplesse** : Être capable de pivoter rapidement et de reconfigurer l'organisation face à une crise est crucial pour éviter la paralysie. L'adaptabilité radicale permet à l'entreprise d'opérer avec succès sous forte incertitude.
#
# 5. **Préparation aux Scénarios** : Adopter la règle des scénarios en préparant plusieurs réalités possibles permet de réduire l'impact de la panique lors d'une crise. Avoir des réponses opérationnelles prêtes pour différents scénarios assure une capacité d'action supérieure.
#
# 6. **Innovation et Créativité** : Transformer les contraintes locales en solutions innovantes et développer des modèles d'affaires adaptés au contexte local peut offrir un avantage concurrentiel significatif.
#
# 7. **Intégration Verticale et Réseaux Durables** : Maîtriser l'intégralité du processus, de la production à la distribution, et construire des alliances inter-entreprises solides peut renforcer la résilience face aux perturbations externes.
#
# En intégrant ces éléments dans sa stratégie, une entreprise peut non seulement survivre mais aussi tirer parti des perturbations pour se renforcer et croître dans un environnement instable.
#
#
#
# === ANSWER TO QUESTION 6 ===
# Quels sont les principaux risques auxquels un entrepreneur est confronté dans un contexte chaotique, et comment les gérer ?
#
# Dans un contexte chaotique tel que celui décrit en République Démocratique du Congo, les entrepreneurs font face à une multitude de risques qui peuvent menacer la pérennité de leurs entreprises. Voici les principaux risques identifiés et des stratégies pour les gérer efficacement :
#
# 1. **Risque Réglementaire et Politique** : Les changements soudains dans la législation ou les politiques économiques peuvent affecter la rentabilité et la stratégie d'une entreprise. Pour gérer ce risque, il est crucial de maintenir une veille réglementaire active et de développer des relations solides avec les parties prenantes locales pour anticiper et s'adapter rapidement aux changements.
#
# 2. **Risque Monétaire et Économique** : La volatilité monétaire peut déstabiliser les prévisions budgétaires et affecter la trésorerie. Une gestion rigoureuse du cash-flow, la constitution de réserves financières, et l'utilisation d'instruments financiers pour se couvrir contre les fluctuations sont essentielles.
#
# 3. **Risque Logistique et Infrastructurel** : Les infrastructures dégradées et les ruptures d'approvisionnement nécessitent une planification logistique flexible. L'entrepreneur doit investir dans des solutions logistiques innovantes et développer des partenariats locaux pour sécuriser ses chaînes d'approvisionnement.
#
# 4. **Risque Sécuritaire** : L'insécurité peut menacer les actifs physiques et le personnel. Il est important de mettre en place des mesures de sécurité robustes, telles que l'assurance des actifs, la formation du personnel à la gestion des crises, et l'établissement de plans de continuité d'activité.
#
# 5. **Risque Humain** : La loyauté du personnel est cruciale dans un environnement où la corruption est présente. Investir dans le développement des compétences, instaurer une culture d'entreprise forte, et assurer une communication transparente sont des stratégies efficaces pour renforcer l'engagement des équipes.
#
# 6. **Risque Psychologique** : L'usure mentale due à l'incertitude constante peut affecter la prise de décision. Il est vital pour l'entrepreneur de développer sa résilience personnelle, par exemple en s'entourant de mentors ou en participant à des réseaux d'entrepreneurs pour partager les expériences et obtenir du soutien.
#
# En conclusion, dans un environnement chaotique, l'entrepreneur doit adopter une stratégie adaptative qui intègre ces risques comme des éléments structurels plutôt que des anomalies temporaires. La clé réside dans la capacité à transformer ces défis en opportunités stratégiques, en développant une entreprise anti-fragile qui non seulement survit aux chocs mais en tire parti pour croître et se renforcer.
#
#
#
# === ANSWER TO QUESTION 7 ===
# Comment maintenir la motivation et la cohésion d’une équipe lorsque l’environnement externe devient incertain ?
#
# Pour maintenir la motivation et la cohésion d'une équipe dans un environnement externe incertain, il est crucial de se concentrer sur plusieurs axes stratégiques qui favorisent la résilience collective et individuelle. Voici quelques recommandations pratiques basées sur le contexte fourni :
#
# 1. **Cultiver la Résilience Collective**: La résilience n'est pas l'absence de difficultés, mais la capacité à maintenir l'élan malgré l'adversité. Encouragez une culture où les échecs sont vus comme des opportunités d'apprentissage. Cela aide à renforcer la robustesse psychologique de l'équipe.
#
# 2. **Discipline Stratégique**: Dans un environnement chaotique, la discipline devient une arme puissante. Établissez des processus clairs et assurez-vous que l'équipe y adhère fermement. Cela limite l'impact du chaos extérieur et garantit la reproductibilité des succès.
#
# 3. **Leadership Éclairé**: Un bon leader protège son équipe comme un chef d'état-major protège son armée. Sélectionnez soigneusement votre personnel en fonction de leur capacité à gérer le stress et à rester calmes sous pression. Remplacez rapidement les éléments qui ne s'adaptent pas pour protéger la cohésion de l'équipe.
#
# 4. **Communication Transparente**: Maintenez une communication ouverte et honnête avec votre équipe. Partagez les défis auxquels l'entreprise est confrontée et impliquez-les dans le processus de prise de décision. Cela renforce leur engagement et leur sentiment d'appartenance.
#
# 5. **Flexibilité et Adaptation**: Encouragez une culture d'apprentissage continu où l'équipe est prête à désapprendre des méthodes obsolètes et à s'adapter rapidement aux nouvelles technologies ou régulations. La souplesse d'adaptation est essentielle pour éviter la paralysie face aux crises.
#
# 6. **Opportunités dans le Chaos**: Aidez votre équipe à voir les opportunités qui émergent dans l'instabilité. L'incertitude peut être un catalyseur pour l'innovation et la croissance si elle est abordée avec une mentalité anti-fragile.
#
# 7. **Soutien Psychologique**: Reconnaissez que l'incertitude peut être psychologiquement éprouvante. Offrez des ressources pour soutenir le bien-être mental de votre équipe, comme des ateliers de gestion du stress ou des séances de coaching.
#
# En intégrant ces stratégies, vous pouvez non seulement maintenir la motivation et la cohésion de votre équipe, mais aussi transformer les défis externes en leviers pour renforcer votre organisation.
#
#
#
# === ANSWER TO QUESTION 8 ===
# Quelles stratégies permettent de naviguer efficacement dans un marché en transformation rapide ?
#
# Pour naviguer efficacement dans un marché en transformation rapide, plusieurs stratégies clés émergent du contexte fourni. Voici une réponse claire, pratique et orientée terrain :
#
# 1. **Souplesse Stratégique et Réinvention** : L'entrepreneur doit être prêt à pivoter rapidement. Cela peut inclure le changement de produit ou de service pour mieux répondre aux besoins réels du marché, la modification du modèle économique pour s'adapter aux contraintes locales, ou encore la redéfinition de la clientèle cible. Cette flexibilité est cruciale pour éviter l'épuisement des ressources et maintenir la crédibilité.
#
# 2. **Adaptation Permanente** : Dans un environnement instable comme celui du Congo, l'adaptation est plus précieuse que la force brute ou l'intelligence académique. Cela implique une veille active des signaux faibles et une capacité à ajuster les modèles d'affaires sans délai. L'entrepreneur doit changer plus vite que son environnement pour survivre et prospérer.
#
# 3. **Diversification Stratégique** : Construire une entreprise anti-fragile nécessite de diversifier les sources de revenus, les clients, et les canaux de distribution. Cela réduit la dépendance à un seul facteur et permet à l'entreprise de résister aux chocs externes.
#
# 4. **Utilisation des Failles Systémiques** : Identifier les inefficiences structurelles, les vides institutionnels, et les besoins non couverts par le système formel peut transformer le chaos en opportunité. L'entrepreneur doit voir ces failles comme des demandes de solutions privées de substitution.
#
# 5. **Partenariats Stratégiques** : Dans un marché en transformation rapide, nul ne peut maîtriser seul toutes les compétences nécessaires. Le succès durable repose sur des partenariats fondés sur la complémentarité et une vision partagée.
#
# 6. **Résilience Collective et Robustesse sous Pression** : Former des équipes capables de gérer le stress et l'incertitude est essentiel. La résilience collective permet non seulement de survivre mais aussi d'optimiser les systèmes sous pression.
#
# 7. **Préparation aux Scénarios Multiples** : Adopter une approche basée sur plusieurs scénarios possibles permet de mieux gérer l'incertitude. Avoir des plans opérationnels prêts pour différents scénarios réduit l'impact de la panique lors d'une crise.
#
# En résumé, naviguer dans un marché en transformation rapide exige une combinaison de souplesse stratégique, adaptation continue, diversification, exploitation des failles systémiques, partenariats stratégiques solides, résilience collective, et préparation aux scénarios multiples. Ces stratégies permettent non seulement de survivre mais aussi de transformer l'instabilité en opportunité de croissance durable.
#
#
#
# === ANSWER TO QUESTION 9 ===
# Comment un entrepreneur peut-il repenser son modèle économique pour survivre ou prospérer dans le chaos ?
#
# Pour qu'un entrepreneur puisse repenser son modèle économique et prospérer dans un environnement chaotique, il est crucial de se concentrer sur plusieurs aspects clés qui exploitent le chaos comme une opportunité plutôt qu'une menace. Voici quelques stratégies pratiques basées sur le contexte fourni :
#
# 1. **Adopter une mentalité anti-fragile** : Plutôt que de simplement résister au chaos, un entrepreneur doit apprendre à en tirer parti. Cela signifie développer des systèmes qui non seulement survivent aux chocs, mais qui s'améliorent grâce à eux. Par exemple, diversifier les sources de revenus et les canaux de distribution peut transformer la volatilité en avantage concurrentiel.
#
# 2. **Flexibilité et adaptation rapide** : Dans un environnement instable comme celui de la RDC, la capacité à pivoter rapidement est essentielle. Cela implique d'être prêt à modifier les modèles d'affaires en réponse aux signaux faibles du marché et aux changements soudains dans l'environnement économique ou politique.
#
# 3. **Exploiter les inefficacités structurelles** : Identifier les failles dans le système actuel, telles que les infrastructures obsolètes ou les services publics déficients, peut ouvrir des opportunités pour offrir des solutions alternatives. Les entrepreneurs peuvent combler ces lacunes par des innovations qui répondent aux besoins non satisfaits.
#
# 4. **Construire des réserves financières** : Maintenir un flux de trésorerie positif et constituer des réserves financières permet de résister aux périodes difficiles et d'investir stratégiquement lorsque d'autres acteurs se retirent.
#
# 5. **Créer des chaînes de valeur intégrées** : En contrôlant plusieurs maillons de la chaîne de production et de distribution, un entrepreneur peut mieux gérer les risques liés à la volatilité des prix et à l'approvisionnement.
#
# 6. **Développer une intelligence situationnelle** : Comprendre profondément le contexte local, y compris les dynamiques politiques et économiques invisibles, permet de prendre des décisions éclairées et stratégiques.
#
# 7. **Cultiver la résilience organisationnelle** : Former des équipes capables de gérer le stress et l'incertitude est crucial. La résilience collective aide l'entreprise à naviguer dans les crises sans perdre sa cohésion ni sa direction stratégique.
#
# 8. **Naviguer dans l'incertitude réglementaire avec pragmatisme** : Accepter que l'incertitude réglementaire fait partie du paysage et développer des stratégies pour maintenir l'intégrité éthique tout en protégeant l'entreprise contre le chantage ou les pressions externes.
#
# En somme, pour prospérer dans le chaos, un entrepreneur doit transformer l'instabilité en une force motrice pour l'innovation et la croissance, tout en restant agile et prêt à saisir les opportunités émergentes.
#
#
#
# === ANSWER TO QUESTION 10 ===
# Quel rôle joue l’innovation dans la capacité d’une entreprise à s’adapter à des conditions extrêmes ?
#
# L'innovation joue un rôle crucial dans la capacité d'une entreprise à s'adapter à des conditions extrêmes, comme celles décrites dans le contexte congolais. Voici comment l'innovation peut être intégrée dans une stratégie d'entreprise pour renforcer sa résilience et sa capacité d'adaptation :
#
# 1. **Adaptabilité Radicale**: L'innovation permet aux entreprises de pivoter rapidement et de s'adapter à des environnements incertains. Cela inclut la capacité de changer de produit, de modèle économique ou de clientèle en réponse aux fluctuations du marché. Par exemple, une entreprise peut développer de nouveaux produits ou services qui répondent mieux aux besoins émergents des consommateurs.
#
# 2. **Résolution de Problèmes Complexes**: Dans un environnement chaotique, l'innovation est essentielle pour transformer les contraintes locales en opportunités. Cela peut inclure le développement de solutions logistiques innovantes pour surmonter les défis d'infrastructure ou la création de modèles économiques adaptés aux réalités locales.
#
# 3. **Maîtrise Technologique Appliquée**: L'innovation technologique est un levier puissant pour améliorer l'efficacité opérationnelle et réduire les coûts. Les entreprises peuvent utiliser la technologie pour optimiser leurs processus internes, améliorer leur chaîne d'approvisionnement et offrir des solutions numériques adaptées aux besoins locaux.
#
# 4. **Créativité Constructive**: L'innovation encourage la création de modèles d'affaires inédits qui échappent aux schémas traditionnels. Cela peut inclure l'exploration de nouveaux canaux de distribution ou l'intégration verticale pour réduire la dépendance à des fournisseurs externes.
#
# 5. **Antifragilité**: L'innovation contribue à bâtir une entreprise antifragile, qui non seulement résiste aux chocs mais en tire parti pour se renforcer. Cela implique une diversification stratégique des sources de revenus, des clients et des canaux de distribution pour minimiser les risques systémiques.
#
# 6. **Opportunités Émergentes**: Dans le chaos, l'innovation permet d'identifier et d'exploiter des niches inexploitées ou mal desservies par le marché actuel. Les entrepreneurs innovants peuvent ainsi créer de la valeur là où d'autres voient uniquement du risque.
#
# En résumé, l'innovation est un moteur essentiel pour transformer les défis posés par un environnement instable en opportunités stratégiques. Elle permet non seulement de survivre mais aussi de prospérer en période de chaos, en renforçant la résilience structurelle et en stimulant la croissance durable.
#
#
#
# === ANSWER TO QUESTION 11 ===
# Comment développer une vision claire et mobilisatrice lorsque le futur est difficile à anticiper ?
#
# Pour développer une vision claire et mobilisatrice dans un contexte où le futur est difficile à anticiper, il est essentiel d'adopter une approche stratégique qui intègre la résilience, l'adaptabilité et une compréhension profonde de l'environnement chaotique. Voici quelques étapes pratiques basées sur le contexte fourni :
#
# 1. **Adopter la règle des scénarios** : Ne vous fiez pas uniquement à un scénario idéal. Préparez-vous à plusieurs réalités possibles en cartographiant les menaces majeures. Cela vous permettra de réagir rapidement et efficacement lorsque des crises surviennent, car vous aurez déjà des plans d'action validés.
#
# 2. **Cultiver la résilience** : La résilience n'est pas seulement une qualité morale, mais une compétence stratégique essentielle. Elle implique de maintenir le cap malgré les interruptions et de se relever après les échecs. En RDC, cela constitue un avantage concurrentiel décisif.
#
# 3. **Embrasser l'instabilité comme norme** : Considérez l'instabilité non pas comme une anomalie, mais comme un élément structurel de votre environnement. Cela nécessite de concevoir votre entreprise pour qu'elle prospère dans le désordre, en intégrant la volatilité comme paramètre de conception.
#
# 4. **Construire une entreprise anti-fragile** : Transformez votre entreprise pour qu'elle tire profit des chocs et du stress. Cela passe par la diversification stratégique, évitant la dépendance à un client unique ou à une seule source de revenus.
#
# 5. **Développer une vision civilisationnelle** : Pensez au-delà de la simple rentabilité économique. Visez à créer des structures capables de survivre à leur fondateur, établissant ainsi un héritage durable.
#
# 6. **Pratiquer la discipline stratégique** : La discipline doit être votre constante face au chaos extérieur. Elle vous permet de maintenir l'effort et l'action délibérée même lorsque la motivation faiblit.
#
# 7. **Identifier les opportunités dans le chaos** : Là où d'autres voient du désordre, identifiez des architectures économiques en devenir. Le chaos peut révéler des opportunités vastes que seule une vision stratégique peut exploiter.
#
# En résumé, pour développer une vision claire et mobilisatrice dans un environnement incertain, il est crucial d'intégrer la résilience structurelle, d'adopter une approche flexible et adaptative, et de voir au-delà des défis immédiats pour identifier les opportunités stratégiques cachées dans le chaos.

# %%
query_keywords_bonus = [
    # Thèmes centraux
    "chaos", "incertitude", "résilience", "opportunité", "crise",
    "stratégie", "adaptation", "leadership", "risque", "transformation",
    "signal faible", "modèle économique", "innovation",

    # Ajout précédent
    "vision", "agilité", "perturbation", "changement", "conflit",
    "décision", "priorité", "organisation", "stress", "complexité",
    "survie", "pivot", "reconstruction",

    # Nouveaux mots (doublement enrichis)
    "anticipation", "intuition", "résolution", "effondrement", "rebond",
    "opportunisme", "résistance", "solidarité", "communication", "mobilisation",
    "alignement", "cohésion", "urgence", "fragilité", "stabilité",
    "vision long terme", "réinvention", "réorientation", "analyse",
    "diagnostic", "proactivité", "réactivité", "turbulence", "désordre",
    "systémique", "efficacité", "priorisation", "réallocation", "capacité",
    "endurance", "persévérance", "audace", "initiative", "créativité",
    "rupture", "transition", "incidence", "impact", "résultats"
]


for i, docs in enumerate(results_bonus) :
    for j, doc in enumerate(docs[:1]):
        text = doc.page_content # RETRIVE THE TEXT
        snippet = text[:1000] # EXTRACT A SNIPPET
        highlighted = highlight_keywords([snippet], query_keywords_bonus) # HIGHLIGHT_KEYWORDS EXPECTS A LIST OF STRINGS
        print(f"Snippet {j+1}:\n{highlighted[0]}\n{'-'*80}")
# Out:
# Snippet 1:
# ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS
#
# 411
#
# Dans le chaos, les systèmes rigides, lourds de bureaucratie ou
# d’une inertie forte, échouent. L’environnement les brise. Les sys-
# tèmes adaptatifs, eux, prospèrent. Leur souplesse structurelle est
# leur première arme concurrentielle.
# L’entrepreneur stratège ne gaspille pas son énergie à éradiquer
# le chaos. Une telle ambition relève de l’illusion. Son effort porte
# sur sa compréhension profonde et son utilisation.
# Il dresse une cartographie précise :
# ● Les zones d’inefficience structurelle : Ce sont les failles
# du système (distribution lacunaire, services publics défi-
# cients, infrastructures obsolètes). Pour l’entrepreneur,
# elles se muent en demande de solutions privées de subs-
# titution.
# ● Les vides institutionnels ou légaux : Là où l’État est ab-
# sent ou la loi incertaine, une place existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
# --------------------------------------------------------------------------------
# Snippet 1:
# ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# --------------------------------------------------------------------------------
# Snippet 1:
# sent ou la loi incertaine, une place existe pour celui qui
# propose un cadre clair ou un service de confiance.
# ● Les besoins non couverts par le système formel : L’accès
# à la finance, à l’énergie, à l’éducation de qualité pour la
# majorité de la population. Ce déficit incarne un marché
# colossal.
# ● Les flux informels de l’économie : Il apprend à décoder
# les circuits de l’ombre, la logique des marchés populaires,
# source d’une trésorerie réelle.
# ● Les ruptures structurelles (politique, technologique, géo-
# politique) : Chaque choc crée une réorganisation du pou-
# voir et des marchés, offrant un avantage aux premiers
# positionnés.
# Fort de cette analyse, l’entrepreneur construit son œuvre à
# partir de ces éléments, non contre eux.
# Ce renversement de perspective est une action fondatrice : Le
# chaos ne constitue pas un obstacle rédhibitoire à la création de
# --------------------------------------------------------------------------------
# Snippet 1:
# cation produit vigoureuse ou à une politique de réduc-
# tion des coûts drastique et rapide.
# Chacun de ces scénarios doit avoir une réponse opération-
# nelle rédigée, connue, et prête à être exécutée.
# Cette préparation réduit l’impact de la panique. Lorsque la
# crise advient, l'équipe ne cherche pas une solution sous le coup
# de l'urgence. Elle exécute un plan déjà validé, gage de survie et
# de maintien de la trajectoire stratégique. Le stratège congolais
# sait : la prévision donne une puissance d’action supérieure.
# --------------------------------------------------------------------------------
# Snippet 1:
# tenir, de continuer l’investissement stratégique quand les
# concurrents subissent un repli brutal.
# Dans un environnement où l’instabilité structurelle est la
# norme, la possession d’une réserve financière saine ne relève pas
# du confort. Elle représente une exigence vitale, un levier de sou-
# veraineté pour l’entreprise face aux pressions externes. Le capital
# disponible confère la liberté d’action et la force de négociation.
#
#
# Construire une entreprise anti -
# fragile : le principe de la résilience
# dynamique
# --------------------------------------------------------------------------------
# Snippet 1:
# ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS
#
# 343
#
# d’une forteresse interne, vulnérables à la moindre bourrasque du
# chaos environnant. L’entrepreneur stratège est celui qui fait de la
# survie un avantage concurrentiel majeur.
#
#
# Le risque n’est pas l’ennemi
#
# Beaucoup associent l’entreprise, l’action d’entreprendre, au
# courage. Ce lien est vrai. L'audace initie l’élan, mais elle doit se
# distinguer d’une imprudence stérile. Le véritable entrepreneur
# n’est point celui qui accepte tous les risques, par pure téméri té.
# C’est la figure qui comprend la nature profonde du risque, qui
# évalue avec lucidité ceux qu’il choisit de prendre, et ceux qu’il
# doit absolument neutraliser.
# En République Démocratique du Congo, le risque ne consti-
# tue pas un bloc monolithique à rejeter, il représente un prisme
# complexe. Il devient alors impératif d’analyser plusieurs catégo-
# ries de risques, car une stratégie d’entreprise solide repose sur
# --------------------------------------------------------------------------------
# Snippet 1:
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# de prospérer là où les autres s’effondrent.
# Un leadership éclairé sélectionne son personnel en fonction
# de ce prisme d’évaluation. Ces qualités forgent une équipe non
# pas réactive, mais véritablement anti-fragile.
#
#
# Embaucher lentement, remplacer
# rapidement
# --------------------------------------------------------------------------------
# Snippet 1:
# 372
#
# évoluent sans cesse, cette rigidité est un risque mortel. L'opéra-
# teur qui s’entête à poursuivre une voie non viable finit par épui-
# ser son capital, son temps, et sa crédibilité.
# La survie exige une souplesse stratégique, une aptitude réelle
# à la réinvention. Il faut accepter que le succès passe par une mu-
# tation profonde de l'entreprise :
# ● Changer de produit ou de service : Les besoins réels des
# populations ou des entreprises peuvent différer de l’offre
# pensée au départ. Le pivot stratégique, souvent incon-
# fortable, est une nécessité vitale.
# ● Changer de modèle économique : Un système de tarifi-
# cation ou de distribution inadapté au contexte congolais
# (logistique lourde, faible pouvoir d'achat) voue le projet
# à l'échec. L'exploration de nouveaux circuits de revenus
# est capitale.
# ● Changer de clientèle (segmentation) : Le marché peut re-
# jeter la cible envisagée ou, à l'inverse, révéler un segment
# plus porteur mais ignoré au départ (l’accès à la diaspora,
# --------------------------------------------------------------------------------
# Snippet 1:
# 356
#
# Le chaos, loin de représenter une force de destruction pure,
# constitue un environnement naturel pour l'entrepreneur congo-
# lais. Ce contexte impose un changement de paradigme, passant
# de la simple survie à une croissance provoquée par la perturba-
# tion.
# Une entreprise peut se définir selon son interaction avec l’in-
# certitude :
# 1. L’entreprise fragile est une structure qui subit le chaos,
# où le moindre choc se révèle une source de dégât majeur.
# Sa rigidité la destine à la rupture.
# 2. L’entreprise robuste cherche l'endurance. Elle supporte
# le chaos, il glisse sur elle, mais ne crée aucune valeur. Elle
# maintient son état initial, une posture statique face au
# mouvement du marché.
# 3. L’entreprise anti-fragile excède la simple résilience. Elle
# tire profit des chocs, du stress, de la volatilité pour gran-
# dir, gagner en force et optimiser ses systèmes. Elle trouve
# dans le désordre une puissance motrice.
# Comment un entrepreneur en RDC peut -il ériger une telle
# --------------------------------------------------------------------------------
# Snippet 1:
# ENTREPRENDRE DANS LE CHAOS 1 E. CHRISTIAN BOSMANS
#
# 365
#
# obsolètes et à s’adapter aux technologies ou aux régula-
# tions nouvelles représente un avantage concurrentiel ma-
# jeur.
# ● La loyauté structurelle : Dans un climat d’affaires où la
# corruption et les changements d’alliances sont des
# risques constants, la loyauté du personnel clef est un
# rempart. Elle assure la protection des informations stra-
# tégiques et la cohésion de l'entreprise face aux pressions
# externes.
# ● La souplesse d’adaptation : Être en mesure de pivoter
# vite, de reconfigurer l’organisation face à une crise poli-
# tique, une dévaluation monétaire ou un problème logis-
# tique soudain. Cette qualité évite la paralysie.
# ● La robustesse sous pression : Un environnement instable
# exige des équipes d’une solidité psychologique supé-
# rieure. La résilience collective, la gestion froide des situa-
# tions critiques et l'absence de panique constituent le filtre
# qui permet à l’entreprise de non seulement survivre, mais
# --------------------------------------------------------------------------------
# Snippet 1:
# 350
#
# Une question simple doit devenir automatique :
# “ Qu’est-ce qui pourrait interrompre mon activité demain ? “
# Puis :
# “ Que puis-je faire aujourd’hui pour réduire cette menace ? “
#
#
# La règle des scénarios
#
# L'approche opérationnelle de nombre d’entreprises congo-
# laises repose sur un unique postulat : le scénario idéal. Cette pro-
# jection, dangereuse, ignore la nature volatile de l'environnement
# d'affaires à Kinshasa, Lubumbashi ou Goma.
# Un stratège d'entreprise, à l'inverse, prépare l’action à partir
# de plusieurs réalités possibles, cartographiant le chaos pour
# mieux le dominer. Adopter la règle des scénarios impose une
# discipline de guerre, celle qui envisage le pire pour pouvoir y faire
# face avec force.
# Cette méthode se structure autour de l'identification des me-
# naces majeures :
# ● Scénario A : La Croissance Normale (Le Rêve)
# Toutes les variables économiques, logistiques et poli-
# tiques évoluent favorablement. Il s’agit du plan de con-
# quête optimal.
# --------------------------------------------------------------------------------
